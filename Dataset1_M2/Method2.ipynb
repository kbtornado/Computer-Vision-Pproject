# %%
# !pip install opencv-python
import numpy as np
import pandas as pd
import os
import csv
import cv2
import matplotlib.pyplot as plt
import pickle
import joblib
from sklearn.svm import SVC
from skimage.feature import hog
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score 
from sklearn.metrics import accuracy_score,f1_score, classification_report, confusion_matrix , accuracy_score, precision_score, recall_score, f1_score, roc_curve ,roc_auc_score,ConfusionMatrixDisplay
# Out:
# Requirement already satisfied: opencv-python in c:\users\lenovo\anaconda3\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\lenovo\anaconda3\lib\site-packages (from opencv-python) (1.21.5)

# %% [markdown]
# Path Definition: Paths for four folders are defined, each containing images of different categories of brain scans: glioma tumor, meningioma tumor, no tumor, and pituitary tumor.

# %%
#Path of dataset
folder1="glioma_tumor"
folder2="meningioma_tumor"
folder3="no_tumor"
folder4="pituitary_tumor"

# %% [markdown]
# #### Feature Extraction Using HOG

# %% [markdown]
# Feature Extraction Using HOG (Histogram of Oriented Gradients): The core of this script lies in extracting features from the images using the Histogram of Oriented Gradients (HOG) method. This process is repeated for each folder (each tumor type). The steps for feature extraction include:
#
# Reading each image from the dataset.
# Resizing images to a standard size (200x200 pixels) to ensure uniformity.
# Converting images to grayscale, which is a common preprocessing step in image processing to reduce complexity while retaining essential features.
# Applying a median filter with a 3x3 kernel to reduce noise in the images, which helps in highlighting important features while suppressing irrelevant details.
# Extracting HOG features from the preprocessed images. HOG is a feature descriptor that is particularly effective for object detection in computer vision. It works by counting occurrences of gradient orientation in localized portions of an image.
# Data Structuring and Storage: After extracting the HOG descriptors, they are stored in a pandas DataFrame, with each row representing the HOG feature vector of an image. A 'Class' column is added to this DataFrame to label the data according to the type of tumor (or absence thereof) it represents. This labeling is crucial for supervised learning tasks.
#
# Saving the Data: The feature vectors along with their labels are saved into .npy files for each category of brain scans. This file format is efficient for storing and accessing large arrays, making it suitable for machine learning tasks.

# %%
hog_descs = []
i = 0
for filename in os.listdir(folder1):
    # print(os.path.join(folder_path, filename))
    img = cv2.imread(os.path.join(folder1, filename))
    if img is not None:
        
        #resize total  image size to 200 x 200
        resize=(200,200)
        img1=cv2.resize(img,resize)
        
        # Grayscaling the image dataset
        gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        
        # Apply median filter with kernel size 3x3
        median_img = cv2.medianBlur(gray, 3)
    
        fd, hog_image = hog(median_img, orientations=6, pixels_per_cell=(4, 4),  transform_sqrt=True,cells_per_block=(1, 1), visualize=True)
        # Convert the descriptor array into a DataFrame format
        hog_descs.append(fd)
        df = pd.DataFrame(fd)
        # print(df)
        print("descriptor shape ", i, " : ", df.shape)
        i = i + 1

df = pd.DataFrame(hog_descs)
i = 0
#add row of class
df["Class"] = i

#Storing previously saved feature descriptor to numpy file .
np.save("glioma.npy", df.to_numpy())
# Out:
# descriptor shape  0  :  (15000, 1)
# descriptor shape  1  :  (15000, 1)
# descriptor shape  2  :  (15000, 1)
# descriptor shape  3  :  (15000, 1)
# descriptor shape  4  :  (15000, 1)
# descriptor shape  5  :  (15000, 1)
# descriptor shape  6  :  (15000, 1)
# descriptor shape  7  :  (15000, 1)
# descriptor shape  8  :  (15000, 1)
# descriptor shape  9  :  (15000, 1)
# descriptor shape  10  :  (15000, 1)
# descriptor shape  11  :  (15000, 1)
# descriptor shape  12  :  (15000, 1)
# descriptor shape  13  :  (15000, 1)
# descriptor shape  14  :  (15000, 1)
# descriptor shape  15  :  (15000, 1)
# descriptor shape  16  :  (15000, 1)
# descriptor shape  17  :  (15000, 1)
# descriptor shape  95  :  (15000, 1)
# descriptor shape  96  :  (15000, 1)
# descriptor shape  97  :  (15000, 1)
# descriptor shape  98  :  (15000, 1)
# descriptor shape  99  :  (15000, 1)
# descriptor shape  100  :  (15000, 1)
# descriptor shape  101  :  (15000, 1)
# descriptor shape  102  :  (15000, 1)
# descriptor shape  103  :  (15000, 1)
# descriptor shape  104  :  (15000, 1)
# descriptor shape  105  :  (15000, 1)
# descriptor shape  106  :  (15000, 1)
# descriptor shape  107  :  (15000, 1)
# descriptor shape  108  :  (15000, 1)
# descriptor shape  109  :  (15000, 1)
# descriptor shape  110  :  (15000, 1)
# descriptor shape  111  :  (15000, 1)
# descriptor shape  112  :  (15000, 1)
# descriptor shape  113  :  (15000, 1)
# descriptor shape  114  :  (15000, 1)
# descriptor shape  115  :  (15000, 1)
# descriptor shape  116  :  (15000, 1)
# descriptor shape  117  :  (15000, 1)
# descriptor shape  118  :  (15000, 1)
# descriptor shape  119  :  (15000, 1)
# descriptor shape  120  :  (15000, 1)
# descriptor shape  121  :  (15000, 1)
# descriptor shape  122  :  (15000, 1)
# descriptor shape  123  :  (15000, 1)
# descriptor shape  124  :  (15000, 1)
# descriptor shape  125  :  (15000, 1)
# descriptor shape  126  :  (15000, 1)
# descriptor shape  127  :  (15000, 1)
# descriptor shape  128  :  (15000, 1)
# descriptor shape  129  :  (15000, 1)
# descriptor shape  130  :  (15000, 1)
# descriptor shape  131  :  (15000, 1)
# descriptor shape  132  :  (15000, 1)
# descriptor shape  133  :  (15000, 1)
# descriptor shape  134  :  (15000, 1)
# descriptor shape  135  :  (15000, 1)
# descriptor shape  136  :  (15000, 1)
# descriptor shape  137  :  (15000, 1)
# descriptor shape  138  :  (15000, 1)
# descriptor shape  139  :  (15000, 1)
# descriptor shape  140  :  (15000, 1)
# descriptor shape  141  :  (15000, 1)
# descriptor shape  142  :  (15000, 1)
# descriptor shape  143  :  (15000, 1)
# descriptor shape  144  :  (15000, 1)
# descriptor shape  145  :  (15000, 1)
# descriptor shape  146  :  (15000, 1)
# descriptor shape  147  :  (15000, 1)
# descriptor shape  148  :  (15000, 1)
# descriptor shape  149  :  (15000, 1)
# descriptor shape  150  :  (15000, 1)
# descriptor shape  151  :  (15000, 1)
# descriptor shape  152  :  (15000, 1)
# descriptor shape  153  :  (15000, 1)
# descriptor shape  154  :  (15000, 1)
# descriptor shape  155  :  (15000, 1)
# descriptor shape  156  :  (15000, 1)
# descriptor shape  157  :  (15000, 1)
# descriptor shape  158  :  (15000, 1)
# descriptor shape  159  :  (15000, 1)
# descriptor shape  160  :  (15000, 1)
# descriptor shape  161  :  (15000, 1)
# descriptor shape  162  :  (15000, 1)
# descriptor shape  163  :  (15000, 1)
# descriptor shape  164  :  (15000, 1)
# descriptor shape  165  :  (15000, 1)
# descriptor shape  166  :  (15000, 1)
# descriptor shape  167  :  (15000, 1)
# descriptor shape  168  :  (15000, 1)
# descriptor shape  169  :  (15000, 1)
# descriptor shape  170  :  (15000, 1)
# descriptor shape  248  :  (15000, 1)
# descriptor shape  249  :  (15000, 1)
# descriptor shape  250  :  (15000, 1)
# descriptor shape  251  :  (15000, 1)
# descriptor shape  252  :  (15000, 1)
# descriptor shape  253  :  (15000, 1)
# descriptor shape  254  :  (15000, 1)
# descriptor shape  255  :  (15000, 1)
# descriptor shape  256  :  (15000, 1)
# descriptor shape  257  :  (15000, 1)
# descriptor shape  258  :  (15000, 1)
# descriptor shape  259  :  (15000, 1)
# descriptor shape  260  :  (15000, 1)
# descriptor shape  261  :  (15000, 1)
# descriptor shape  262  :  (15000, 1)
# descriptor shape  263  :  (15000, 1)
# descriptor shape  264  :  (15000, 1)
# descriptor shape  265  :  (15000, 1)
# descriptor shape  266  :  (15000, 1)
# descriptor shape  267  :  (15000, 1)
# descriptor shape  268  :  (15000, 1)
# descriptor shape  269  :  (15000, 1)
# descriptor shape  270  :  (15000, 1)
# descriptor shape  271  :  (15000, 1)
# descriptor shape  272  :  (15000, 1)
# descriptor shape  273  :  (15000, 1)
# descriptor shape  274  :  (15000, 1)
# descriptor shape  275  :  (15000, 1)
# descriptor shape  276  :  (15000, 1)
# descriptor shape  277  :  (15000, 1)
# descriptor shape  278  :  (15000, 1)
# descriptor shape  279  :  (15000, 1)
# descriptor shape  280  :  (15000, 1)
# descriptor shape  281  :  (15000, 1)
# descriptor shape  282  :  (15000, 1)
# descriptor shape  283  :  (15000, 1)
# descriptor shape  284  :  (15000, 1)
# descriptor shape  285  :  (15000, 1)
# descriptor shape  286  :  (15000, 1)
# descriptor shape  287  :  (15000, 1)
# descriptor shape  288  :  (15000, 1)
# descriptor shape  289  :  (15000, 1)
# descriptor shape  290  :  (15000, 1)
# descriptor shape  291  :  (15000, 1)
# descriptor shape  292  :  (15000, 1)
# descriptor shape  293  :  (15000, 1)
# descriptor shape  294  :  (15000, 1)
# descriptor shape  295  :  (15000, 1)
# descriptor shape  296  :  (15000, 1)
# descriptor shape  297  :  (15000, 1)
# descriptor shape  298  :  (15000, 1)
# descriptor shape  299  :  (15000, 1)
# descriptor shape  300  :  (15000, 1)
# descriptor shape  301  :  (15000, 1)
# descriptor shape  302  :  (15000, 1)
# descriptor shape  303  :  (15000, 1)
# descriptor shape  304  :  (15000, 1)
# descriptor shape  305  :  (15000, 1)
# descriptor shape  306  :  (15000, 1)
# descriptor shape  307  :  (15000, 1)
# descriptor shape  308  :  (15000, 1)
# descriptor shape  309  :  (15000, 1)
# descriptor shape  310  :  (15000, 1)
# descriptor shape  311  :  (15000, 1)
# descriptor shape  312  :  (15000, 1)
# descriptor shape  313  :  (15000, 1)
# descriptor shape  314  :  (15000, 1)
# descriptor shape  315  :  (15000, 1)
# descriptor shape  316  :  (15000, 1)
# descriptor shape  317  :  (15000, 1)
# descriptor shape  318  :  (15000, 1)
# descriptor shape  319  :  (15000, 1)
# descriptor shape  320  :  (15000, 1)
# descriptor shape  321  :  (15000, 1)
# descriptor shape  322  :  (15000, 1)
# descriptor shape  323  :  (15000, 1)
# descriptor shape  324  :  (15000, 1)
# descriptor shape  479  :  (15000, 1)
# descriptor shape  480  :  (15000, 1)
# descriptor shape  481  :  (15000, 1)
# descriptor shape  482  :  (15000, 1)
# descriptor shape  483  :  (15000, 1)
# descriptor shape  484  :  (15000, 1)
# descriptor shape  485  :  (15000, 1)
# descriptor shape  486  :  (15000, 1)
# descriptor shape  487  :  (15000, 1)
# descriptor shape  488  :  (15000, 1)
# descriptor shape  489  :  (15000, 1)
# descriptor shape  490  :  (15000, 1)
# descriptor shape  491  :  (15000, 1)
# descriptor shape  492  :  (15000, 1)
# descriptor shape  493  :  (15000, 1)
# descriptor shape  494  :  (15000, 1)
# descriptor shape  495  :  (15000, 1)
# descriptor shape  496  :  (15000, 1)
# descriptor shape  497  :  (15000, 1)
# descriptor shape  498  :  (15000, 1)
# descriptor shape  499  :  (15000, 1)
# descriptor shape  500  :  (15000, 1)
# descriptor shape  501  :  (15000, 1)
# descriptor shape  502  :  (15000, 1)
# descriptor shape  503  :  (15000, 1)
# descriptor shape  504  :  (15000, 1)
# descriptor shape  505  :  (15000, 1)
# descriptor shape  506  :  (15000, 1)
# descriptor shape  507  :  (15000, 1)
# descriptor shape  508  :  (15000, 1)
# descriptor shape  509  :  (15000, 1)
# descriptor shape  510  :  (15000, 1)
# descriptor shape  511  :  (15000, 1)
# descriptor shape  512  :  (15000, 1)
# descriptor shape  513  :  (15000, 1)
# descriptor shape  514  :  (15000, 1)
# descriptor shape  515  :  (15000, 1)
# descriptor shape  516  :  (15000, 1)
# descriptor shape  517  :  (15000, 1)
# descriptor shape  518  :  (15000, 1)
# descriptor shape  519  :  (15000, 1)
# descriptor shape  520  :  (15000, 1)
# descriptor shape  521  :  (15000, 1)
# descriptor shape  522  :  (15000, 1)
# descriptor shape  523  :  (15000, 1)
# descriptor shape  524  :  (15000, 1)
# descriptor shape  525  :  (15000, 1)
# descriptor shape  526  :  (15000, 1)
# descriptor shape  527  :  (15000, 1)
# descriptor shape  528  :  (15000, 1)
# descriptor shape  529  :  (15000, 1)
# descriptor shape  530  :  (15000, 1)
# descriptor shape  531  :  (15000, 1)
# descriptor shape  532  :  (15000, 1)
# descriptor shape  533  :  (15000, 1)
# descriptor shape  534  :  (15000, 1)
# descriptor shape  535  :  (15000, 1)
# descriptor shape  536  :  (15000, 1)
# descriptor shape  537  :  (15000, 1)
# descriptor shape  538  :  (15000, 1)
# descriptor shape  539  :  (15000, 1)
# descriptor shape  540  :  (15000, 1)
# descriptor shape  541  :  (15000, 1)
# descriptor shape  542  :  (15000, 1)
# descriptor shape  543  :  (15000, 1)
# descriptor shape  544  :  (15000, 1)
# descriptor shape  545  :  (15000, 1)
# descriptor shape  546  :  (15000, 1)
# descriptor shape  547  :  (15000, 1)
# descriptor shape  548  :  (15000, 1)
# descriptor shape  549  :  (15000, 1)
# descriptor shape  550  :  (15000, 1)
# descriptor shape  551  :  (15000, 1)
# descriptor shape  552  :  (15000, 1)
# descriptor shape  553  :  (15000, 1)
# descriptor shape  554  :  (15000, 1)
# descriptor shape  555  :  (15000, 1)
# descriptor shape  556  :  (15000, 1)
# descriptor shape  557  :  (15000, 1)
# descriptor shape  558  :  (15000, 1)
# descriptor shape  559  :  (15000, 1)
# descriptor shape  560  :  (15000, 1)
# descriptor shape  561  :  (15000, 1)
# descriptor shape  562  :  (15000, 1)
# descriptor shape  563  :  (15000, 1)
# descriptor shape  564  :  (15000, 1)
# descriptor shape  565  :  (15000, 1)
# descriptor shape  566  :  (15000, 1)
# descriptor shape  567  :  (15000, 1)
# descriptor shape  568  :  (15000, 1)
# descriptor shape  569  :  (15000, 1)
# descriptor shape  570  :  (15000, 1)
# descriptor shape  571  :  (15000, 1)
# descriptor shape  572  :  (15000, 1)
# descriptor shape  573  :  (15000, 1)
# descriptor shape  574  :  (15000, 1)
# descriptor shape  575  :  (15000, 1)
# descriptor shape  576  :  (15000, 1)
# descriptor shape  577  :  (15000, 1)
# descriptor shape  578  :  (15000, 1)
# descriptor shape  579  :  (15000, 1)
# descriptor shape  580  :  (15000, 1)
# descriptor shape  581  :  (15000, 1)
# descriptor shape  582  :  (15000, 1)
# descriptor shape  583  :  (15000, 1)
# descriptor shape  584  :  (15000, 1)
# descriptor shape  585  :  (15000, 1)
# descriptor shape  586  :  (15000, 1)
# descriptor shape  587  :  (15000, 1)
# descriptor shape  588  :  (15000, 1)
# descriptor shape  589  :  (15000, 1)
# descriptor shape  590  :  (15000, 1)
# descriptor shape  591  :  (15000, 1)
# descriptor shape  592  :  (15000, 1)
# descriptor shape  593  :  (15000, 1)
# descriptor shape  594  :  (15000, 1)
# descriptor shape  595  :  (15000, 1)
# descriptor shape  596  :  (15000, 1)
# descriptor shape  597  :  (15000, 1)
# descriptor shape  598  :  (15000, 1)
# descriptor shape  599  :  (15000, 1)
# descriptor shape  600  :  (15000, 1)
# descriptor shape  601  :  (15000, 1)
# descriptor shape  602  :  (15000, 1)
# descriptor shape  603  :  (15000, 1)
# descriptor shape  604  :  (15000, 1)
# descriptor shape  605  :  (15000, 1)
# descriptor shape  606  :  (15000, 1)
# descriptor shape  607  :  (15000, 1)
# descriptor shape  608  :  (15000, 1)
# descriptor shape  609  :  (15000, 1)
# descriptor shape  610  :  (15000, 1)
# descriptor shape  611  :  (15000, 1)
# descriptor shape  612  :  (15000, 1)
# descriptor shape  613  :  (15000, 1)
# descriptor shape  614  :  (15000, 1)
# descriptor shape  615  :  (15000, 1)
# descriptor shape  616  :  (15000, 1)
# descriptor shape  617  :  (15000, 1)
# descriptor shape  618  :  (15000, 1)
# descriptor shape  619  :  (15000, 1)
# descriptor shape  620  :  (15000, 1)
# descriptor shape  621  :  (15000, 1)
# descriptor shape  622  :  (15000, 1)
# descriptor shape  623  :  (15000, 1)
# descriptor shape  624  :  (15000, 1)
# descriptor shape  625  :  (15000, 1)
# descriptor shape  626  :  (15000, 1)
# descriptor shape  627  :  (15000, 1)
# descriptor shape  628  :  (15000, 1)
# descriptor shape  629  :  (15000, 1)
# descriptor shape  630  :  (15000, 1)
# descriptor shape  631  :  (15000, 1)
# descriptor shape  632  :  (15000, 1)
# descriptor shape  710  :  (15000, 1)
# descriptor shape  711  :  (15000, 1)
# descriptor shape  712  :  (15000, 1)
# descriptor shape  713  :  (15000, 1)
# descriptor shape  714  :  (15000, 1)
# descriptor shape  715  :  (15000, 1)
# descriptor shape  716  :  (15000, 1)
# descriptor shape  717  :  (15000, 1)
# descriptor shape  718  :  (15000, 1)
# descriptor shape  719  :  (15000, 1)
# descriptor shape  720  :  (15000, 1)
# descriptor shape  721  :  (15000, 1)
# descriptor shape  722  :  (15000, 1)
# descriptor shape  723  :  (15000, 1)
# descriptor shape  724  :  (15000, 1)
# descriptor shape  725  :  (15000, 1)
# descriptor shape  726  :  (15000, 1)
# descriptor shape  727  :  (15000, 1)
# descriptor shape  728  :  (15000, 1)
# descriptor shape  729  :  (15000, 1)
# descriptor shape  730  :  (15000, 1)
# descriptor shape  731  :  (15000, 1)
# descriptor shape  732  :  (15000, 1)
# descriptor shape  733  :  (15000, 1)
# descriptor shape  734  :  (15000, 1)
# descriptor shape  735  :  (15000, 1)
# descriptor shape  736  :  (15000, 1)
# descriptor shape  737  :  (15000, 1)
# descriptor shape  738  :  (15000, 1)
# descriptor shape  739  :  (15000, 1)
# descriptor shape  740  :  (15000, 1)
# descriptor shape  741  :  (15000, 1)
# descriptor shape  742  :  (15000, 1)
# descriptor shape  743  :  (15000, 1)
# descriptor shape  744  :  (15000, 1)
# descriptor shape  745  :  (15000, 1)
# descriptor shape  746  :  (15000, 1)
# descriptor shape  747  :  (15000, 1)
# descriptor shape  748  :  (15000, 1)
# descriptor shape  749  :  (15000, 1)
# descriptor shape  750  :  (15000, 1)
# descriptor shape  751  :  (15000, 1)
# descriptor shape  752  :  (15000, 1)
# descriptor shape  753  :  (15000, 1)
# descriptor shape  754  :  (15000, 1)
# descriptor shape  755  :  (15000, 1)
# descriptor shape  756  :  (15000, 1)
# descriptor shape  757  :  (15000, 1)
# descriptor shape  758  :  (15000, 1)
# descriptor shape  759  :  (15000, 1)
# descriptor shape  760  :  (15000, 1)
# descriptor shape  761  :  (15000, 1)
# descriptor shape  762  :  (15000, 1)
# descriptor shape  763  :  (15000, 1)
# descriptor shape  764  :  (15000, 1)
# descriptor shape  765  :  (15000, 1)
# descriptor shape  766  :  (15000, 1)
# descriptor shape  767  :  (15000, 1)
# descriptor shape  768  :  (15000, 1)
# descriptor shape  769  :  (15000, 1)
# descriptor shape  770  :  (15000, 1)
# descriptor shape  771  :  (15000, 1)
# descriptor shape  772  :  (15000, 1)
# descriptor shape  773  :  (15000, 1)
# descriptor shape  774  :  (15000, 1)
# descriptor shape  775  :  (15000, 1)
# descriptor shape  776  :  (15000, 1)
# descriptor shape  777  :  (15000, 1)
# descriptor shape  778  :  (15000, 1)
# descriptor shape  779  :  (15000, 1)
# descriptor shape  780  :  (15000, 1)
# descriptor shape  781  :  (15000, 1)
# descriptor shape  782  :  (15000, 1)
# descriptor shape  783  :  (15000, 1)
# descriptor shape  784  :  (15000, 1)
# descriptor shape  785  :  (15000, 1)
# descriptor shape  786  :  (15000, 1)
# descriptor shape  787  :  (15000, 1)
# descriptor shape  788  :  (15000, 1)
# descriptor shape  789  :  (15000, 1)
# descriptor shape  790  :  (15000, 1)
# descriptor shape  791  :  (15000, 1)
# descriptor shape  792  :  (15000, 1)
# descriptor shape  793  :  (15000, 1)
# descriptor shape  794  :  (15000, 1)
# descriptor shape  795  :  (15000, 1)
# descriptor shape  796  :  (15000, 1)
# descriptor shape  797  :  (15000, 1)
# descriptor shape  798  :  (15000, 1)
# descriptor shape  799  :  (15000, 1)
# descriptor shape  800  :  (15000, 1)
# descriptor shape  801  :  (15000, 1)
# descriptor shape  802  :  (15000, 1)
# descriptor shape  803  :  (15000, 1)
# descriptor shape  804  :  (15000, 1)
# descriptor shape  805  :  (15000, 1)
# descriptor shape  806  :  (15000, 1)
# descriptor shape  807  :  (15000, 1)
# descriptor shape  808  :  (15000, 1)
# descriptor shape  809  :  (15000, 1)
# descriptor shape  810  :  (15000, 1)
# descriptor shape  811  :  (15000, 1)
# descriptor shape  812  :  (15000, 1)
# descriptor shape  813  :  (15000, 1)
# descriptor shape  814  :  (15000, 1)
# descriptor shape  815  :  (15000, 1)
# descriptor shape  816  :  (15000, 1)
# descriptor shape  817  :  (15000, 1)
# descriptor shape  818  :  (15000, 1)
# descriptor shape  819  :  (15000, 1)
# descriptor shape  820  :  (15000, 1)
# descriptor shape  821  :  (15000, 1)
# descriptor shape  822  :  (15000, 1)
# descriptor shape  823  :  (15000, 1)
# descriptor shape  824  :  (15000, 1)
# descriptor shape  825  :  (15000, 1)

# %%
#Folder 2 (Meningioma Tumor)
hog_descs = []
i = 0
for filename in os.listdir(folder2):
    # print(os.path.join(folder_path, filename))
    img = cv2.imread(os.path.join(folder2, filename))
    if img is not None:
        #resize total  image size to 200 x 200
        resize=(200,200)
        img1=cv2.resize(img,resize)
        
        # Grayscaling the image dataset
        gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        
        # Apply median filter with kernel size 3x3
        median_img = cv2.medianBlur(gray, 3)

        fd, hog_image = hog(median_img, orientations=6, pixels_per_cell=(4, 4),  transform_sqrt=True,cells_per_block=(1, 1), visualize=True)
        # Convert the descriptor array into a DataFrame format
        hog_descs.append(fd)
        df = pd.DataFrame(fd)
        # print(df)
        print("descriptor shape ", i, " : ", df.shape)
        i = i + 1

df = pd.DataFrame(hog_descs)
i = 1
#add row class
df["Class"] = i

#Storing previously saved feature descriptor to numpy file .
np.save("meningioma.npy", df.to_numpy())
# Out:
# descriptor shape  0  :  (15000, 1)
# descriptor shape  1  :  (15000, 1)
# descriptor shape  2  :  (15000, 1)
# descriptor shape  3  :  (15000, 1)
# descriptor shape  4  :  (15000, 1)
# descriptor shape  5  :  (15000, 1)
# descriptor shape  6  :  (15000, 1)
# descriptor shape  7  :  (15000, 1)
# descriptor shape  8  :  (15000, 1)
# descriptor shape  9  :  (15000, 1)
# descriptor shape  10  :  (15000, 1)
# descriptor shape  11  :  (15000, 1)
# descriptor shape  12  :  (15000, 1)
# descriptor shape  13  :  (15000, 1)
# descriptor shape  14  :  (15000, 1)
# descriptor shape  15  :  (15000, 1)
# descriptor shape  16  :  (15000, 1)
# descriptor shape  17  :  (15000, 1)
# descriptor shape  18  :  (15000, 1)
# descriptor shape  481  :  (15000, 1)
# descriptor shape  482  :  (15000, 1)
# descriptor shape  483  :  (15000, 1)
# descriptor shape  484  :  (15000, 1)
# descriptor shape  485  :  (15000, 1)
# descriptor shape  486  :  (15000, 1)
# descriptor shape  487  :  (15000, 1)
# descriptor shape  488  :  (15000, 1)
# descriptor shape  489  :  (15000, 1)
# descriptor shape  490  :  (15000, 1)
# descriptor shape  491  :  (15000, 1)
# descriptor shape  492  :  (15000, 1)
# descriptor shape  493  :  (15000, 1)
# descriptor shape  494  :  (15000, 1)
# descriptor shape  495  :  (15000, 1)
# descriptor shape  496  :  (15000, 1)
# descriptor shape  497  :  (15000, 1)
# descriptor shape  498  :  (15000, 1)
# descriptor shape  499  :  (15000, 1)
# descriptor shape  500  :  (15000, 1)
# descriptor shape  501  :  (15000, 1)
# descriptor shape  502  :  (15000, 1)
# descriptor shape  503  :  (15000, 1)
# descriptor shape  504  :  (15000, 1)
# descriptor shape  505  :  (15000, 1)
# descriptor shape  506  :  (15000, 1)
# descriptor shape  507  :  (15000, 1)
# descriptor shape  508  :  (15000, 1)
# descriptor shape  509  :  (15000, 1)
# descriptor shape  510  :  (15000, 1)
# descriptor shape  511  :  (15000, 1)
# descriptor shape  512  :  (15000, 1)
# descriptor shape  513  :  (15000, 1)
# descriptor shape  514  :  (15000, 1)
# descriptor shape  515  :  (15000, 1)
# descriptor shape  516  :  (15000, 1)
# descriptor shape  517  :  (15000, 1)
# descriptor shape  518  :  (15000, 1)
# descriptor shape  519  :  (15000, 1)
# descriptor shape  520  :  (15000, 1)
# descriptor shape  521  :  (15000, 1)
# descriptor shape  522  :  (15000, 1)
# descriptor shape  523  :  (15000, 1)
# descriptor shape  524  :  (15000, 1)
# descriptor shape  525  :  (15000, 1)
# descriptor shape  526  :  (15000, 1)
# descriptor shape  527  :  (15000, 1)
# descriptor shape  528  :  (15000, 1)
# descriptor shape  529  :  (15000, 1)
# descriptor shape  530  :  (15000, 1)
# descriptor shape  531  :  (15000, 1)
# descriptor shape  532  :  (15000, 1)
# descriptor shape  533  :  (15000, 1)
# descriptor shape  534  :  (15000, 1)
# descriptor shape  535  :  (15000, 1)
# descriptor shape  536  :  (15000, 1)
# descriptor shape  537  :  (15000, 1)
# descriptor shape  538  :  (15000, 1)
# descriptor shape  539  :  (15000, 1)
# descriptor shape  540  :  (15000, 1)
# descriptor shape  541  :  (15000, 1)
# descriptor shape  542  :  (15000, 1)
# descriptor shape  543  :  (15000, 1)
# descriptor shape  544  :  (15000, 1)
# descriptor shape  545  :  (15000, 1)
# descriptor shape  546  :  (15000, 1)
# descriptor shape  547  :  (15000, 1)
# descriptor shape  548  :  (15000, 1)
# descriptor shape  549  :  (15000, 1)
# descriptor shape  550  :  (15000, 1)
# descriptor shape  551  :  (15000, 1)
# descriptor shape  552  :  (15000, 1)
# descriptor shape  553  :  (15000, 1)
# descriptor shape  554  :  (15000, 1)
# descriptor shape  555  :  (15000, 1)
# descriptor shape  556  :  (15000, 1)
# descriptor shape  557  :  (15000, 1)
# descriptor shape  558  :  (15000, 1)
# descriptor shape  559  :  (15000, 1)
# descriptor shape  560  :  (15000, 1)
# descriptor shape  561  :  (15000, 1)
# descriptor shape  562  :  (15000, 1)
# descriptor shape  563  :  (15000, 1)
# descriptor shape  564  :  (15000, 1)
# descriptor shape  565  :  (15000, 1)
# descriptor shape  566  :  (15000, 1)
# descriptor shape  567  :  (15000, 1)
# descriptor shape  568  :  (15000, 1)
# descriptor shape  569  :  (15000, 1)
# descriptor shape  570  :  (15000, 1)
# descriptor shape  571  :  (15000, 1)
# descriptor shape  572  :  (15000, 1)
# descriptor shape  573  :  (15000, 1)
# descriptor shape  574  :  (15000, 1)
# descriptor shape  575  :  (15000, 1)
# descriptor shape  576  :  (15000, 1)
# descriptor shape  577  :  (15000, 1)
# descriptor shape  578  :  (15000, 1)
# descriptor shape  579  :  (15000, 1)
# descriptor shape  580  :  (15000, 1)
# descriptor shape  581  :  (15000, 1)
# descriptor shape  582  :  (15000, 1)
# descriptor shape  583  :  (15000, 1)
# descriptor shape  584  :  (15000, 1)
# descriptor shape  585  :  (15000, 1)
# descriptor shape  586  :  (15000, 1)
# descriptor shape  587  :  (15000, 1)
# descriptor shape  588  :  (15000, 1)
# descriptor shape  589  :  (15000, 1)
# descriptor shape  590  :  (15000, 1)
# descriptor shape  591  :  (15000, 1)
# descriptor shape  592  :  (15000, 1)
# descriptor shape  593  :  (15000, 1)
# descriptor shape  594  :  (15000, 1)
# descriptor shape  595  :  (15000, 1)
# descriptor shape  596  :  (15000, 1)
# descriptor shape  597  :  (15000, 1)
# descriptor shape  598  :  (15000, 1)
# descriptor shape  599  :  (15000, 1)
# descriptor shape  600  :  (15000, 1)
# descriptor shape  601  :  (15000, 1)
# descriptor shape  602  :  (15000, 1)
# descriptor shape  603  :  (15000, 1)
# descriptor shape  604  :  (15000, 1)
# descriptor shape  605  :  (15000, 1)
# descriptor shape  606  :  (15000, 1)
# descriptor shape  607  :  (15000, 1)
# descriptor shape  608  :  (15000, 1)
# descriptor shape  609  :  (15000, 1)
# descriptor shape  610  :  (15000, 1)
# descriptor shape  611  :  (15000, 1)
# descriptor shape  612  :  (15000, 1)
# descriptor shape  613  :  (15000, 1)
# descriptor shape  614  :  (15000, 1)
# descriptor shape  615  :  (15000, 1)
# descriptor shape  616  :  (15000, 1)
# descriptor shape  617  :  (15000, 1)
# descriptor shape  618  :  (15000, 1)
# descriptor shape  619  :  (15000, 1)
# descriptor shape  620  :  (15000, 1)
# descriptor shape  621  :  (15000, 1)
# descriptor shape  622  :  (15000, 1)
# descriptor shape  623  :  (15000, 1)
# descriptor shape  624  :  (15000, 1)
# descriptor shape  625  :  (15000, 1)
# descriptor shape  626  :  (15000, 1)
# descriptor shape  627  :  (15000, 1)
# descriptor shape  628  :  (15000, 1)
# descriptor shape  629  :  (15000, 1)
# descriptor shape  630  :  (15000, 1)
# descriptor shape  631  :  (15000, 1)
# descriptor shape  632  :  (15000, 1)
# descriptor shape  633  :  (15000, 1)
# descriptor shape  634  :  (15000, 1)
# descriptor shape  712  :  (15000, 1)
# descriptor shape  713  :  (15000, 1)
# descriptor shape  714  :  (15000, 1)
# descriptor shape  715  :  (15000, 1)
# descriptor shape  716  :  (15000, 1)
# descriptor shape  717  :  (15000, 1)
# descriptor shape  718  :  (15000, 1)
# descriptor shape  719  :  (15000, 1)
# descriptor shape  720  :  (15000, 1)
# descriptor shape  721  :  (15000, 1)
# descriptor shape  722  :  (15000, 1)
# descriptor shape  723  :  (15000, 1)
# descriptor shape  724  :  (15000, 1)
# descriptor shape  725  :  (15000, 1)
# descriptor shape  726  :  (15000, 1)
# descriptor shape  727  :  (15000, 1)
# descriptor shape  728  :  (15000, 1)
# descriptor shape  729  :  (15000, 1)
# descriptor shape  730  :  (15000, 1)
# descriptor shape  731  :  (15000, 1)
# descriptor shape  732  :  (15000, 1)
# descriptor shape  733  :  (15000, 1)
# descriptor shape  734  :  (15000, 1)
# descriptor shape  735  :  (15000, 1)
# descriptor shape  736  :  (15000, 1)
# descriptor shape  737  :  (15000, 1)
# descriptor shape  738  :  (15000, 1)
# descriptor shape  739  :  (15000, 1)
# descriptor shape  740  :  (15000, 1)
# descriptor shape  741  :  (15000, 1)
# descriptor shape  742  :  (15000, 1)
# descriptor shape  743  :  (15000, 1)
# descriptor shape  744  :  (15000, 1)
# descriptor shape  745  :  (15000, 1)
# descriptor shape  746  :  (15000, 1)
# descriptor shape  747  :  (15000, 1)
# descriptor shape  748  :  (15000, 1)
# descriptor shape  749  :  (15000, 1)
# descriptor shape  750  :  (15000, 1)
# descriptor shape  751  :  (15000, 1)
# descriptor shape  752  :  (15000, 1)
# descriptor shape  753  :  (15000, 1)
# descriptor shape  754  :  (15000, 1)
# descriptor shape  755  :  (15000, 1)
# descriptor shape  756  :  (15000, 1)
# descriptor shape  757  :  (15000, 1)
# descriptor shape  758  :  (15000, 1)
# descriptor shape  759  :  (15000, 1)
# descriptor shape  760  :  (15000, 1)
# descriptor shape  761  :  (15000, 1)
# descriptor shape  762  :  (15000, 1)
# descriptor shape  763  :  (15000, 1)
# descriptor shape  764  :  (15000, 1)
# descriptor shape  765  :  (15000, 1)
# descriptor shape  766  :  (15000, 1)
# descriptor shape  767  :  (15000, 1)
# descriptor shape  768  :  (15000, 1)
# descriptor shape  769  :  (15000, 1)
# descriptor shape  770  :  (15000, 1)
# descriptor shape  771  :  (15000, 1)
# descriptor shape  772  :  (15000, 1)
# descriptor shape  773  :  (15000, 1)
# descriptor shape  774  :  (15000, 1)
# descriptor shape  775  :  (15000, 1)
# descriptor shape  776  :  (15000, 1)
# descriptor shape  777  :  (15000, 1)
# descriptor shape  778  :  (15000, 1)
# descriptor shape  779  :  (15000, 1)
# descriptor shape  780  :  (15000, 1)
# descriptor shape  781  :  (15000, 1)
# descriptor shape  782  :  (15000, 1)
# descriptor shape  783  :  (15000, 1)
# descriptor shape  784  :  (15000, 1)
# descriptor shape  785  :  (15000, 1)
# descriptor shape  786  :  (15000, 1)
# descriptor shape  787  :  (15000, 1)
# descriptor shape  788  :  (15000, 1)
# descriptor shape  789  :  (15000, 1)
# descriptor shape  790  :  (15000, 1)
# descriptor shape  791  :  (15000, 1)
# descriptor shape  792  :  (15000, 1)
# descriptor shape  793  :  (15000, 1)
# descriptor shape  794  :  (15000, 1)
# descriptor shape  795  :  (15000, 1)
# descriptor shape  796  :  (15000, 1)
# descriptor shape  797  :  (15000, 1)
# descriptor shape  798  :  (15000, 1)
# descriptor shape  799  :  (15000, 1)
# descriptor shape  800  :  (15000, 1)
# descriptor shape  801  :  (15000, 1)
# descriptor shape  802  :  (15000, 1)
# descriptor shape  803  :  (15000, 1)
# descriptor shape  804  :  (15000, 1)
# descriptor shape  805  :  (15000, 1)
# descriptor shape  806  :  (15000, 1)
# descriptor shape  807  :  (15000, 1)
# descriptor shape  808  :  (15000, 1)
# descriptor shape  809  :  (15000, 1)
# descriptor shape  810  :  (15000, 1)
# descriptor shape  811  :  (15000, 1)
# descriptor shape  812  :  (15000, 1)
# descriptor shape  813  :  (15000, 1)
# descriptor shape  814  :  (15000, 1)
# descriptor shape  815  :  (15000, 1)
# descriptor shape  816  :  (15000, 1)
# descriptor shape  817  :  (15000, 1)
# descriptor shape  818  :  (15000, 1)
# descriptor shape  819  :  (15000, 1)
# descriptor shape  820  :  (15000, 1)
# descriptor shape  821  :  (15000, 1)

# %%
#Folder 3 (No tumor)
hog_descs = []
i = 0
for filename in os.listdir(folder3):
    # print(os.path.join(folder_path, filename))
    img = cv2.imread(os.path.join(folder3, filename))
    if img is not None:
        #resize total  image size to 200 x 200
        resize=(200,200)
        img1=cv2.resize(img,resize)

        # Grayscaling the image dataset
        gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        
        # Apply median filter with kernel size 3x3
        median_img = cv2.medianBlur(gray, 3)

        fd, hog_image = hog(median_img, orientations=6, pixels_per_cell=(4, 4),  transform_sqrt=True,cells_per_block=(1, 1), visualize=True)
        # Convert the descriptor array into a DataFrame format
        hog_descs.append(fd)
        df = pd.DataFrame(fd)
        # print(df)
        print("descriptor shape ", i, " : ", df.shape)
        i = i + 1

df = pd.DataFrame(hog_descs)
i = 2
#add row class
df["Class"] = i

#Storing previously saved feature descriptor to numpy file .
np.save("notumor.npy", df.to_numpy())
# Out:
# descriptor shape  0  :  (15000, 1)
# descriptor shape  1  :  (15000, 1)
# descriptor shape  2  :  (15000, 1)
# descriptor shape  3  :  (15000, 1)
# descriptor shape  4  :  (15000, 1)
# descriptor shape  5  :  (15000, 1)
# descriptor shape  6  :  (15000, 1)
# descriptor shape  7  :  (15000, 1)
# descriptor shape  8  :  (15000, 1)
# descriptor shape  9  :  (15000, 1)
# descriptor shape  10  :  (15000, 1)
# descriptor shape  11  :  (15000, 1)
# descriptor shape  12  :  (15000, 1)
# descriptor shape  13  :  (15000, 1)
# descriptor shape  14  :  (15000, 1)
# descriptor shape  15  :  (15000, 1)
# descriptor shape  16  :  (15000, 1)
# descriptor shape  17  :  (15000, 1)
# descriptor shape  18  :  (15000, 1)
# descriptor shape  19  :  (15000, 1)
# descriptor shape  20  :  (15000, 1)
# descriptor shape  21  :  (15000, 1)
# descriptor shape  22  :  (15000, 1)
# descriptor shape  23  :  (15000, 1)
# descriptor shape  24  :  (15000, 1)
# descriptor shape  256  :  (15000, 1)
# descriptor shape  257  :  (15000, 1)
# descriptor shape  258  :  (15000, 1)
# descriptor shape  259  :  (15000, 1)
# descriptor shape  260  :  (15000, 1)
# descriptor shape  261  :  (15000, 1)
# descriptor shape  262  :  (15000, 1)
# descriptor shape  263  :  (15000, 1)
# descriptor shape  264  :  (15000, 1)
# descriptor shape  265  :  (15000, 1)
# descriptor shape  266  :  (15000, 1)
# descriptor shape  267  :  (15000, 1)
# descriptor shape  268  :  (15000, 1)
# descriptor shape  269  :  (15000, 1)
# descriptor shape  270  :  (15000, 1)
# descriptor shape  271  :  (15000, 1)
# descriptor shape  272  :  (15000, 1)
# descriptor shape  273  :  (15000, 1)
# descriptor shape  274  :  (15000, 1)
# descriptor shape  275  :  (15000, 1)
# descriptor shape  276  :  (15000, 1)
# descriptor shape  277  :  (15000, 1)
# descriptor shape  278  :  (15000, 1)
# descriptor shape  279  :  (15000, 1)
# descriptor shape  280  :  (15000, 1)
# descriptor shape  281  :  (15000, 1)
# descriptor shape  282  :  (15000, 1)
# descriptor shape  283  :  (15000, 1)
# descriptor shape  284  :  (15000, 1)
# descriptor shape  285  :  (15000, 1)
# descriptor shape  286  :  (15000, 1)
# descriptor shape  287  :  (15000, 1)
# descriptor shape  288  :  (15000, 1)
# descriptor shape  289  :  (15000, 1)
# descriptor shape  290  :  (15000, 1)
# descriptor shape  291  :  (15000, 1)
# descriptor shape  292  :  (15000, 1)
# descriptor shape  293  :  (15000, 1)
# descriptor shape  294  :  (15000, 1)
# descriptor shape  295  :  (15000, 1)
# descriptor shape  296  :  (15000, 1)
# descriptor shape  297  :  (15000, 1)
# descriptor shape  298  :  (15000, 1)
# descriptor shape  299  :  (15000, 1)
# descriptor shape  300  :  (15000, 1)
# descriptor shape  301  :  (15000, 1)
# descriptor shape  302  :  (15000, 1)
# descriptor shape  303  :  (15000, 1)
# descriptor shape  304  :  (15000, 1)
# descriptor shape  305  :  (15000, 1)
# descriptor shape  306  :  (15000, 1)
# descriptor shape  307  :  (15000, 1)
# descriptor shape  308  :  (15000, 1)
# descriptor shape  309  :  (15000, 1)
# descriptor shape  310  :  (15000, 1)
# descriptor shape  311  :  (15000, 1)
# descriptor shape  312  :  (15000, 1)
# descriptor shape  313  :  (15000, 1)
# descriptor shape  314  :  (15000, 1)
# descriptor shape  315  :  (15000, 1)
# descriptor shape  316  :  (15000, 1)
# descriptor shape  317  :  (15000, 1)
# descriptor shape  318  :  (15000, 1)
# descriptor shape  319  :  (15000, 1)
# descriptor shape  320  :  (15000, 1)
# descriptor shape  321  :  (15000, 1)
# descriptor shape  322  :  (15000, 1)
# descriptor shape  323  :  (15000, 1)
# descriptor shape  324  :  (15000, 1)
# descriptor shape  325  :  (15000, 1)
# descriptor shape  326  :  (15000, 1)
# descriptor shape  327  :  (15000, 1)
# descriptor shape  328  :  (15000, 1)
# descriptor shape  329  :  (15000, 1)
# descriptor shape  330  :  (15000, 1)
# descriptor shape  331  :  (15000, 1)
# descriptor shape  332  :  (15000, 1)
# descriptor shape  333  :  (15000, 1)
# descriptor shape  334  :  (15000, 1)
# descriptor shape  335  :  (15000, 1)
# descriptor shape  336  :  (15000, 1)
# descriptor shape  337  :  (15000, 1)
# descriptor shape  338  :  (15000, 1)
# descriptor shape  339  :  (15000, 1)
# descriptor shape  340  :  (15000, 1)
# descriptor shape  341  :  (15000, 1)
# descriptor shape  342  :  (15000, 1)
# descriptor shape  343  :  (15000, 1)
# descriptor shape  344  :  (15000, 1)
# descriptor shape  345  :  (15000, 1)
# descriptor shape  346  :  (15000, 1)
# descriptor shape  347  :  (15000, 1)
# descriptor shape  348  :  (15000, 1)
# descriptor shape  349  :  (15000, 1)
# descriptor shape  350  :  (15000, 1)
# descriptor shape  351  :  (15000, 1)
# descriptor shape  352  :  (15000, 1)
# descriptor shape  353  :  (15000, 1)
# descriptor shape  354  :  (15000, 1)
# descriptor shape  355  :  (15000, 1)
# descriptor shape  356  :  (15000, 1)
# descriptor shape  357  :  (15000, 1)
# descriptor shape  358  :  (15000, 1)
# descriptor shape  359  :  (15000, 1)
# descriptor shape  360  :  (15000, 1)
# descriptor shape  361  :  (15000, 1)
# descriptor shape  362  :  (15000, 1)
# descriptor shape  363  :  (15000, 1)
# descriptor shape  364  :  (15000, 1)
# descriptor shape  365  :  (15000, 1)
# descriptor shape  366  :  (15000, 1)
# descriptor shape  367  :  (15000, 1)
# descriptor shape  368  :  (15000, 1)
# descriptor shape  369  :  (15000, 1)
# descriptor shape  370  :  (15000, 1)
# descriptor shape  371  :  (15000, 1)
# descriptor shape  372  :  (15000, 1)
# descriptor shape  373  :  (15000, 1)
# descriptor shape  374  :  (15000, 1)
# descriptor shape  375  :  (15000, 1)
# descriptor shape  376  :  (15000, 1)
# descriptor shape  377  :  (15000, 1)
# descriptor shape  378  :  (15000, 1)
# descriptor shape  379  :  (15000, 1)
# descriptor shape  380  :  (15000, 1)
# descriptor shape  381  :  (15000, 1)
# descriptor shape  382  :  (15000, 1)
# descriptor shape  383  :  (15000, 1)
# descriptor shape  384  :  (15000, 1)
# descriptor shape  385  :  (15000, 1)
# descriptor shape  386  :  (15000, 1)
# descriptor shape  387  :  (15000, 1)
# descriptor shape  388  :  (15000, 1)
# descriptor shape  389  :  (15000, 1)
# descriptor shape  390  :  (15000, 1)
# descriptor shape  391  :  (15000, 1)
# descriptor shape  392  :  (15000, 1)
# descriptor shape  393  :  (15000, 1)
# descriptor shape  394  :  (15000, 1)

# %%
folder4="pituitary_tumor"
#Folder 4 (Pituitary)
hog_descs = []
i = 0
for filename in os.listdir(folder4):
    # print(os.path.join(folder_path, filename))
    img = cv2.imread(os.path.join(folder4, filename))
    if img is not None:
        #resize total  image size to 200 x 200
        resize=(200,200)
        img1=cv2.resize(img,resize)

        # Grayscaling the image dataset
        gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        
        # Apply median filter with kernel size 3x3
        median_img = cv2.medianBlur(gray, 3)

        fd, hog_image = hog(median_img, orientations=6, pixels_per_cell=(4, 4),  transform_sqrt=True,cells_per_block=(1, 1), visualize=True)
        # Convert the descriptor array into a DataFrame format
        hog_descs.append(fd)
        df = pd.DataFrame(fd)
        # print(df)
        print("descriptor shape ", i, " : ", df.shape)
        i = i + 1

df = pd.DataFrame(hog_descs)
i = 3
#add row class
df["Class"] = i

#Storing previously saved feature descriptor to numpy file .
np.save("pituitary.npy", df.to_numpy())
# Out:
# descriptor shape  0  :  (15000, 1)
# descriptor shape  1  :  (15000, 1)
# descriptor shape  2  :  (15000, 1)
# descriptor shape  3  :  (15000, 1)
# descriptor shape  4  :  (15000, 1)
# descriptor shape  5  :  (15000, 1)
# descriptor shape  6  :  (15000, 1)
# descriptor shape  7  :  (15000, 1)
# descriptor shape  8  :  (15000, 1)
# descriptor shape  9  :  (15000, 1)
# descriptor shape  10  :  (15000, 1)
# descriptor shape  11  :  (15000, 1)
# descriptor shape  12  :  (15000, 1)
# descriptor shape  13  :  (15000, 1)
# descriptor shape  14  :  (15000, 1)
# descriptor shape  15  :  (15000, 1)
# descriptor shape  16  :  (15000, 1)
# descriptor shape  17  :  (15000, 1)
# descriptor shape  18  :  (15000, 1)
# descriptor shape  19  :  (15000, 1)
# descriptor shape  20  :  (15000, 1)
# descriptor shape  21  :  (15000, 1)
# descriptor shape  22  :  (15000, 1)
# descriptor shape  23  :  (15000, 1)
# descriptor shape  24  :  (15000, 1)
# descriptor shape  25  :  (15000, 1)
# descriptor shape  26  :  (15000, 1)
# descriptor shape  27  :  (15000, 1)
# descriptor shape  28  :  (15000, 1)
# descriptor shape  29  :  (15000, 1)
# descriptor shape  30  :  (15000, 1)
# descriptor shape  31  :  (15000, 1)
# descriptor shape  32  :  (15000, 1)
# descriptor shape  33  :  (15000, 1)
# descriptor shape  34  :  (15000, 1)
# descriptor shape  35  :  (15000, 1)
# descriptor shape  36  :  (15000, 1)
# descriptor shape  37  :  (15000, 1)
# descriptor shape  38  :  (15000, 1)
# descriptor shape  39  :  (15000, 1)
# descriptor shape  40  :  (15000, 1)
# descriptor shape  41  :  (15000, 1)
# descriptor shape  42  :  (15000, 1)
# descriptor shape  43  :  (15000, 1)
# descriptor shape  44  :  (15000, 1)
# descriptor shape  45  :  (15000, 1)
# descriptor shape  46  :  (15000, 1)
# descriptor shape  47  :  (15000, 1)
# descriptor shape  48  :  (15000, 1)
# descriptor shape  49  :  (15000, 1)
# descriptor shape  50  :  (15000, 1)
# descriptor shape  51  :  (15000, 1)
# descriptor shape  52  :  (15000, 1)
# descriptor shape  53  :  (15000, 1)
# descriptor shape  54  :  (15000, 1)
# descriptor shape  55  :  (15000, 1)
# descriptor shape  56  :  (15000, 1)
# descriptor shape  57  :  (15000, 1)
# descriptor shape  58  :  (15000, 1)
# descriptor shape  59  :  (15000, 1)
# descriptor shape  60  :  (15000, 1)
# descriptor shape  61  :  (15000, 1)
# descriptor shape  62  :  (15000, 1)
# descriptor shape  63  :  (15000, 1)
# descriptor shape  64  :  (15000, 1)
# descriptor shape  65  :  (15000, 1)
# descriptor shape  66  :  (15000, 1)
# descriptor shape  67  :  (15000, 1)
# descriptor shape  68  :  (15000, 1)
# descriptor shape  69  :  (15000, 1)
# descriptor shape  70  :  (15000, 1)
# descriptor shape  71  :  (15000, 1)
# descriptor shape  226  :  (15000, 1)
# descriptor shape  227  :  (15000, 1)
# descriptor shape  228  :  (15000, 1)
# descriptor shape  229  :  (15000, 1)
# descriptor shape  230  :  (15000, 1)
# descriptor shape  231  :  (15000, 1)
# descriptor shape  232  :  (15000, 1)
# descriptor shape  233  :  (15000, 1)
# descriptor shape  234  :  (15000, 1)
# descriptor shape  235  :  (15000, 1)
# descriptor shape  236  :  (15000, 1)
# descriptor shape  237  :  (15000, 1)
# descriptor shape  238  :  (15000, 1)
# descriptor shape  239  :  (15000, 1)
# descriptor shape  240  :  (15000, 1)
# descriptor shape  241  :  (15000, 1)
# descriptor shape  242  :  (15000, 1)
# descriptor shape  243  :  (15000, 1)
# descriptor shape  244  :  (15000, 1)
# descriptor shape  245  :  (15000, 1)
# descriptor shape  246  :  (15000, 1)
# descriptor shape  247  :  (15000, 1)
# descriptor shape  248  :  (15000, 1)
# descriptor shape  249  :  (15000, 1)
# descriptor shape  250  :  (15000, 1)
# descriptor shape  251  :  (15000, 1)
# descriptor shape  252  :  (15000, 1)
# descriptor shape  253  :  (15000, 1)
# descriptor shape  254  :  (15000, 1)
# descriptor shape  255  :  (15000, 1)
# descriptor shape  256  :  (15000, 1)
# descriptor shape  257  :  (15000, 1)
# descriptor shape  258  :  (15000, 1)
# descriptor shape  259  :  (15000, 1)
# descriptor shape  260  :  (15000, 1)
# descriptor shape  261  :  (15000, 1)
# descriptor shape  262  :  (15000, 1)
# descriptor shape  263  :  (15000, 1)
# descriptor shape  264  :  (15000, 1)
# descriptor shape  265  :  (15000, 1)
# descriptor shape  266  :  (15000, 1)
# descriptor shape  267  :  (15000, 1)
# descriptor shape  268  :  (15000, 1)
# descriptor shape  269  :  (15000, 1)
# descriptor shape  270  :  (15000, 1)
# descriptor shape  271  :  (15000, 1)
# descriptor shape  272  :  (15000, 1)
# descriptor shape  273  :  (15000, 1)
# descriptor shape  274  :  (15000, 1)
# descriptor shape  275  :  (15000, 1)
# descriptor shape  276  :  (15000, 1)
# descriptor shape  277  :  (15000, 1)
# descriptor shape  278  :  (15000, 1)
# descriptor shape  279  :  (15000, 1)
# descriptor shape  280  :  (15000, 1)
# descriptor shape  281  :  (15000, 1)
# descriptor shape  282  :  (15000, 1)
# descriptor shape  283  :  (15000, 1)
# descriptor shape  284  :  (15000, 1)
# descriptor shape  285  :  (15000, 1)
# descriptor shape  286  :  (15000, 1)
# descriptor shape  287  :  (15000, 1)
# descriptor shape  288  :  (15000, 1)
# descriptor shape  289  :  (15000, 1)
# descriptor shape  290  :  (15000, 1)
# descriptor shape  291  :  (15000, 1)
# descriptor shape  292  :  (15000, 1)
# descriptor shape  293  :  (15000, 1)
# descriptor shape  294  :  (15000, 1)
# descriptor shape  295  :  (15000, 1)
# descriptor shape  296  :  (15000, 1)
# descriptor shape  297  :  (15000, 1)
# descriptor shape  298  :  (15000, 1)
# descriptor shape  299  :  (15000, 1)
# descriptor shape  300  :  (15000, 1)
# descriptor shape  301  :  (15000, 1)
# descriptor shape  302  :  (15000, 1)
# descriptor shape  457  :  (15000, 1)
# descriptor shape  458  :  (15000, 1)
# descriptor shape  459  :  (15000, 1)
# descriptor shape  460  :  (15000, 1)
# descriptor shape  461  :  (15000, 1)
# descriptor shape  462  :  (15000, 1)
# descriptor shape  463  :  (15000, 1)
# descriptor shape  464  :  (15000, 1)
# descriptor shape  465  :  (15000, 1)
# descriptor shape  466  :  (15000, 1)
# descriptor shape  467  :  (15000, 1)
# descriptor shape  468  :  (15000, 1)
# descriptor shape  469  :  (15000, 1)
# descriptor shape  470  :  (15000, 1)
# descriptor shape  471  :  (15000, 1)
# descriptor shape  472  :  (15000, 1)
# descriptor shape  473  :  (15000, 1)
# descriptor shape  474  :  (15000, 1)
# descriptor shape  475  :  (15000, 1)
# descriptor shape  476  :  (15000, 1)
# descriptor shape  477  :  (15000, 1)
# descriptor shape  478  :  (15000, 1)
# descriptor shape  479  :  (15000, 1)
# descriptor shape  480  :  (15000, 1)
# descriptor shape  481  :  (15000, 1)
# descriptor shape  482  :  (15000, 1)
# descriptor shape  483  :  (15000, 1)
# descriptor shape  484  :  (15000, 1)
# descriptor shape  485  :  (15000, 1)
# descriptor shape  486  :  (15000, 1)
# descriptor shape  487  :  (15000, 1)
# descriptor shape  488  :  (15000, 1)
# descriptor shape  489  :  (15000, 1)
# descriptor shape  490  :  (15000, 1)
# descriptor shape  491  :  (15000, 1)
# descriptor shape  492  :  (15000, 1)
# descriptor shape  493  :  (15000, 1)
# descriptor shape  494  :  (15000, 1)
# descriptor shape  495  :  (15000, 1)
# descriptor shape  496  :  (15000, 1)
# descriptor shape  497  :  (15000, 1)
# descriptor shape  498  :  (15000, 1)
# descriptor shape  499  :  (15000, 1)
# descriptor shape  500  :  (15000, 1)
# descriptor shape  501  :  (15000, 1)
# descriptor shape  502  :  (15000, 1)
# descriptor shape  503  :  (15000, 1)
# descriptor shape  504  :  (15000, 1)
# descriptor shape  505  :  (15000, 1)
# descriptor shape  506  :  (15000, 1)
# descriptor shape  507  :  (15000, 1)
# descriptor shape  508  :  (15000, 1)
# descriptor shape  509  :  (15000, 1)
# descriptor shape  510  :  (15000, 1)
# descriptor shape  511  :  (15000, 1)
# descriptor shape  512  :  (15000, 1)
# descriptor shape  513  :  (15000, 1)
# descriptor shape  514  :  (15000, 1)
# descriptor shape  515  :  (15000, 1)
# descriptor shape  516  :  (15000, 1)
# descriptor shape  517  :  (15000, 1)
# descriptor shape  518  :  (15000, 1)
# descriptor shape  519  :  (15000, 1)
# descriptor shape  520  :  (15000, 1)
# descriptor shape  521  :  (15000, 1)
# descriptor shape  522  :  (15000, 1)
# descriptor shape  523  :  (15000, 1)
# descriptor shape  524  :  (15000, 1)
# descriptor shape  525  :  (15000, 1)
# descriptor shape  526  :  (15000, 1)
# descriptor shape  527  :  (15000, 1)
# descriptor shape  528  :  (15000, 1)
# descriptor shape  529  :  (15000, 1)
# descriptor shape  530  :  (15000, 1)
# descriptor shape  531  :  (15000, 1)
# descriptor shape  532  :  (15000, 1)
# descriptor shape  533  :  (15000, 1)
# descriptor shape  534  :  (15000, 1)
# descriptor shape  535  :  (15000, 1)
# descriptor shape  536  :  (15000, 1)
# descriptor shape  537  :  (15000, 1)
# descriptor shape  538  :  (15000, 1)
# descriptor shape  539  :  (15000, 1)
# descriptor shape  540  :  (15000, 1)
# descriptor shape  541  :  (15000, 1)
# descriptor shape  542  :  (15000, 1)
# descriptor shape  543  :  (15000, 1)
# descriptor shape  544  :  (15000, 1)
# descriptor shape  545  :  (15000, 1)
# descriptor shape  546  :  (15000, 1)
# descriptor shape  547  :  (15000, 1)
# descriptor shape  548  :  (15000, 1)
# descriptor shape  549  :  (15000, 1)
# descriptor shape  550  :  (15000, 1)
# descriptor shape  551  :  (15000, 1)
# descriptor shape  552  :  (15000, 1)
# descriptor shape  553  :  (15000, 1)
# descriptor shape  554  :  (15000, 1)
# descriptor shape  555  :  (15000, 1)
# descriptor shape  556  :  (15000, 1)
# descriptor shape  557  :  (15000, 1)
# descriptor shape  558  :  (15000, 1)
# descriptor shape  559  :  (15000, 1)
# descriptor shape  560  :  (15000, 1)
# descriptor shape  561  :  (15000, 1)
# descriptor shape  562  :  (15000, 1)
# descriptor shape  563  :  (15000, 1)
# descriptor shape  564  :  (15000, 1)
# descriptor shape  565  :  (15000, 1)
# descriptor shape  566  :  (15000, 1)
# descriptor shape  567  :  (15000, 1)
# descriptor shape  568  :  (15000, 1)
# descriptor shape  569  :  (15000, 1)
# descriptor shape  570  :  (15000, 1)
# descriptor shape  571  :  (15000, 1)
# descriptor shape  572  :  (15000, 1)
# descriptor shape  573  :  (15000, 1)
# descriptor shape  574  :  (15000, 1)
# descriptor shape  575  :  (15000, 1)
# descriptor shape  576  :  (15000, 1)
# descriptor shape  577  :  (15000, 1)
# descriptor shape  578  :  (15000, 1)
# descriptor shape  579  :  (15000, 1)
# descriptor shape  580  :  (15000, 1)
# descriptor shape  581  :  (15000, 1)
# descriptor shape  582  :  (15000, 1)
# descriptor shape  583  :  (15000, 1)
# descriptor shape  584  :  (15000, 1)
# descriptor shape  585  :  (15000, 1)
# descriptor shape  586  :  (15000, 1)
# descriptor shape  587  :  (15000, 1)
# descriptor shape  588  :  (15000, 1)
# descriptor shape  589  :  (15000, 1)
# descriptor shape  590  :  (15000, 1)
# descriptor shape  591  :  (15000, 1)
# descriptor shape  592  :  (15000, 1)
# descriptor shape  593  :  (15000, 1)
# descriptor shape  594  :  (15000, 1)
# descriptor shape  595  :  (15000, 1)
# descriptor shape  596  :  (15000, 1)
# descriptor shape  597  :  (15000, 1)
# descriptor shape  598  :  (15000, 1)
# descriptor shape  599  :  (15000, 1)
# descriptor shape  600  :  (15000, 1)
# descriptor shape  601  :  (15000, 1)
# descriptor shape  602  :  (15000, 1)
# descriptor shape  603  :  (15000, 1)
# descriptor shape  604  :  (15000, 1)
# descriptor shape  605  :  (15000, 1)
# descriptor shape  606  :  (15000, 1)
# descriptor shape  607  :  (15000, 1)
# descriptor shape  608  :  (15000, 1)
# descriptor shape  609  :  (15000, 1)
# descriptor shape  610  :  (15000, 1)
# descriptor shape  611  :  (15000, 1)
# descriptor shape  612  :  (15000, 1)
# descriptor shape  613  :  (15000, 1)
# descriptor shape  614  :  (15000, 1)
# descriptor shape  615  :  (15000, 1)
# descriptor shape  616  :  (15000, 1)
# descriptor shape  617  :  (15000, 1)
# descriptor shape  618  :  (15000, 1)
# descriptor shape  619  :  (15000, 1)
# descriptor shape  620  :  (15000, 1)
# descriptor shape  621  :  (15000, 1)
# descriptor shape  622  :  (15000, 1)
# descriptor shape  623  :  (15000, 1)
# descriptor shape  624  :  (15000, 1)
# descriptor shape  625  :  (15000, 1)
# descriptor shape  626  :  (15000, 1)
# descriptor shape  627  :  (15000, 1)
# descriptor shape  628  :  (15000, 1)
# descriptor shape  629  :  (15000, 1)
# descriptor shape  630  :  (15000, 1)
# descriptor shape  631  :  (15000, 1)
# descriptor shape  632  :  (15000, 1)
# descriptor shape  633  :  (15000, 1)
# descriptor shape  634  :  (15000, 1)
# descriptor shape  635  :  (15000, 1)
# descriptor shape  636  :  (15000, 1)
# descriptor shape  637  :  (15000, 1)
# descriptor shape  638  :  (15000, 1)
# descriptor shape  639  :  (15000, 1)
# descriptor shape  640  :  (15000, 1)
# descriptor shape  641  :  (15000, 1)
# descriptor shape  642  :  (15000, 1)
# descriptor shape  643  :  (15000, 1)
# descriptor shape  644  :  (15000, 1)
# descriptor shape  645  :  (15000, 1)
# descriptor shape  646  :  (15000, 1)
# descriptor shape  647  :  (15000, 1)
# descriptor shape  648  :  (15000, 1)
# descriptor shape  649  :  (15000, 1)
# descriptor shape  650  :  (15000, 1)
# descriptor shape  651  :  (15000, 1)
# descriptor shape  652  :  (15000, 1)
# descriptor shape  653  :  (15000, 1)
# descriptor shape  654  :  (15000, 1)
# descriptor shape  655  :  (15000, 1)
# descriptor shape  656  :  (15000, 1)
# descriptor shape  657  :  (15000, 1)
# descriptor shape  658  :  (15000, 1)
# descriptor shape  659  :  (15000, 1)
# descriptor shape  660  :  (15000, 1)
# descriptor shape  661  :  (15000, 1)
# descriptor shape  662  :  (15000, 1)
# descriptor shape  663  :  (15000, 1)
# descriptor shape  664  :  (15000, 1)
# descriptor shape  665  :  (15000, 1)
# descriptor shape  666  :  (15000, 1)
# descriptor shape  667  :  (15000, 1)
# descriptor shape  668  :  (15000, 1)
# descriptor shape  669  :  (15000, 1)
# descriptor shape  670  :  (15000, 1)
# descriptor shape  671  :  (15000, 1)
# descriptor shape  672  :  (15000, 1)
# descriptor shape  673  :  (15000, 1)
# descriptor shape  674  :  (15000, 1)
# descriptor shape  675  :  (15000, 1)
# descriptor shape  676  :  (15000, 1)
# descriptor shape  677  :  (15000, 1)
# descriptor shape  678  :  (15000, 1)
# descriptor shape  679  :  (15000, 1)
# descriptor shape  680  :  (15000, 1)
# descriptor shape  681  :  (15000, 1)
# descriptor shape  682  :  (15000, 1)
# descriptor shape  683  :  (15000, 1)
# descriptor shape  684  :  (15000, 1)
# descriptor shape  685  :  (15000, 1)
# descriptor shape  686  :  (15000, 1)
# descriptor shape  687  :  (15000, 1)
# descriptor shape  688  :  (15000, 1)
# descriptor shape  689  :  (15000, 1)
# descriptor shape  690  :  (15000, 1)
# descriptor shape  691  :  (15000, 1)
# descriptor shape  692  :  (15000, 1)
# descriptor shape  693  :  (15000, 1)
# descriptor shape  694  :  (15000, 1)
# descriptor shape  695  :  (15000, 1)
# descriptor shape  696  :  (15000, 1)
# descriptor shape  697  :  (15000, 1)
# descriptor shape  698  :  (15000, 1)
# descriptor shape  699  :  (15000, 1)
# descriptor shape  700  :  (15000, 1)
# descriptor shape  701  :  (15000, 1)
# descriptor shape  702  :  (15000, 1)
# descriptor shape  703  :  (15000, 1)
# descriptor shape  704  :  (15000, 1)
# descriptor shape  705  :  (15000, 1)
# descriptor shape  706  :  (15000, 1)
# descriptor shape  707  :  (15000, 1)
# descriptor shape  708  :  (15000, 1)
# descriptor shape  709  :  (15000, 1)
# descriptor shape  710  :  (15000, 1)
# descriptor shape  711  :  (15000, 1)
# descriptor shape  712  :  (15000, 1)
# descriptor shape  713  :  (15000, 1)
# descriptor shape  714  :  (15000, 1)
# descriptor shape  715  :  (15000, 1)
# descriptor shape  716  :  (15000, 1)
# descriptor shape  717  :  (15000, 1)
# descriptor shape  718  :  (15000, 1)
# descriptor shape  719  :  (15000, 1)
# descriptor shape  720  :  (15000, 1)
# descriptor shape  721  :  (15000, 1)
# descriptor shape  722  :  (15000, 1)
# descriptor shape  723  :  (15000, 1)
# descriptor shape  724  :  (15000, 1)
# descriptor shape  725  :  (15000, 1)
# descriptor shape  726  :  (15000, 1)
# descriptor shape  727  :  (15000, 1)
# descriptor shape  728  :  (15000, 1)
# descriptor shape  729  :  (15000, 1)
# descriptor shape  730  :  (15000, 1)
# descriptor shape  731  :  (15000, 1)
# descriptor shape  732  :  (15000, 1)
# descriptor shape  733  :  (15000, 1)
# descriptor shape  734  :  (15000, 1)
# descriptor shape  735  :  (15000, 1)
# descriptor shape  736  :  (15000, 1)
# descriptor shape  737  :  (15000, 1)
# descriptor shape  738  :  (15000, 1)
# descriptor shape  739  :  (15000, 1)
# descriptor shape  740  :  (15000, 1)
# descriptor shape  741  :  (15000, 1)
# descriptor shape  742  :  (15000, 1)
# descriptor shape  743  :  (15000, 1)
# descriptor shape  744  :  (15000, 1)
# descriptor shape  745  :  (15000, 1)
# descriptor shape  746  :  (15000, 1)
# descriptor shape  747  :  (15000, 1)
# descriptor shape  748  :  (15000, 1)
# descriptor shape  749  :  (15000, 1)
# descriptor shape  750  :  (15000, 1)
# descriptor shape  751  :  (15000, 1)
# descriptor shape  752  :  (15000, 1)
# descriptor shape  753  :  (15000, 1)
# descriptor shape  754  :  (15000, 1)
# descriptor shape  755  :  (15000, 1)
# descriptor shape  756  :  (15000, 1)
# descriptor shape  757  :  (15000, 1)
# descriptor shape  758  :  (15000, 1)
# descriptor shape  759  :  (15000, 1)
# descriptor shape  760  :  (15000, 1)
# descriptor shape  761  :  (15000, 1)
# descriptor shape  762  :  (15000, 1)
# descriptor shape  763  :  (15000, 1)
# descriptor shape  764  :  (15000, 1)
# descriptor shape  765  :  (15000, 1)
# descriptor shape  766  :  (15000, 1)
# descriptor shape  767  :  (15000, 1)
# descriptor shape  768  :  (15000, 1)
# descriptor shape  769  :  (15000, 1)
# descriptor shape  770  :  (15000, 1)
# descriptor shape  771  :  (15000, 1)
# descriptor shape  772  :  (15000, 1)
# descriptor shape  773  :  (15000, 1)
# descriptor shape  774  :  (15000, 1)
# descriptor shape  775  :  (15000, 1)
# descriptor shape  776  :  (15000, 1)
# descriptor shape  777  :  (15000, 1)
# descriptor shape  778  :  (15000, 1)
# descriptor shape  779  :  (15000, 1)
# descriptor shape  780  :  (15000, 1)
# descriptor shape  781  :  (15000, 1)
# descriptor shape  782  :  (15000, 1)
# descriptor shape  783  :  (15000, 1)
# descriptor shape  784  :  (15000, 1)
# descriptor shape  785  :  (15000, 1)
# descriptor shape  786  :  (15000, 1)
# descriptor shape  787  :  (15000, 1)
# descriptor shape  788  :  (15000, 1)
# descriptor shape  789  :  (15000, 1)
# descriptor shape  790  :  (15000, 1)
# descriptor shape  791  :  (15000, 1)
# descriptor shape  792  :  (15000, 1)
# descriptor shape  793  :  (15000, 1)
# descriptor shape  794  :  (15000, 1)
# descriptor shape  795  :  (15000, 1)
# descriptor shape  796  :  (15000, 1)
# descriptor shape  797  :  (15000, 1)
# descriptor shape  798  :  (15000, 1)
# descriptor shape  799  :  (15000, 1)
# descriptor shape  800  :  (15000, 1)
# descriptor shape  801  :  (15000, 1)
# descriptor shape  802  :  (15000, 1)
# descriptor shape  803  :  (15000, 1)
# descriptor shape  804  :  (15000, 1)
# descriptor shape  805  :  (15000, 1)
# descriptor shape  806  :  (15000, 1)
# descriptor shape  807  :  (15000, 1)
# descriptor shape  808  :  (15000, 1)
# descriptor shape  809  :  (15000, 1)
# descriptor shape  810  :  (15000, 1)
# descriptor shape  811  :  (15000, 1)
# descriptor shape  812  :  (15000, 1)
# descriptor shape  813  :  (15000, 1)
# descriptor shape  814  :  (15000, 1)
# descriptor shape  815  :  (15000, 1)
# descriptor shape  816  :  (15000, 1)
# descriptor shape  817  :  (15000, 1)
# descriptor shape  818  :  (15000, 1)
# descriptor shape  819  :  (15000, 1)
# descriptor shape  820  :  (15000, 1)
# descriptor shape  821  :  (15000, 1)
# descriptor shape  822  :  (15000, 1)
# descriptor shape  823  :  (15000, 1)
# descriptor shape  824  :  (15000, 1)
# descriptor shape  825  :  (15000, 1)
# descriptor shape  826  :  (15000, 1)

# %% [markdown]
# Loading the HOG Features: The code begins by loading the HOG (Histogram of Oriented Gradients) feature arrays for different classes of brain scans from saved .npy files. These classes include 'glioma', 'meningioma', 'no tumor', and 'pituitary tumor'. Each .npy file contains the HOG feature vectors for the respective class of images, where each row corresponds to the HOG descriptor of an individual image, and the last column represents the class label.
#
# Concatenating Arrays: The individual arrays for each tumor type are concatenated into a single array using np.concatenate(). This operation combines the feature vectors from all the classes along the first axis (rows), resulting in a single array where each row still corresponds to a feature vector from one of the images, and the rows are ordered by the sequence in which the arrays were concatenated.

# %%
# Load the Hog features of All class Glioma, Meningioma, no tumor
glioma_array = np.load('glioma.npy')
meningioma_array = np.load('meningioma.npy')
notumor_array = np.load('notumor.npy')
pitutary_array = np.load('pituitary.npy')

concatenated_array = np.concatenate((glioma_array, meningioma_array,notumor_array,pitutary_array), axis=0)

# prints the shape of the concatenated array
print(concatenated_array.shape)
# Out:
# (2870, 15001)

# %% [markdown]
# Feature and Label Separation:
#
# The features (x) and labels (y) are separated from the concatenated array. The features consist of the HOG descriptors, and the labels represent the class of each image.
# For x, all columns except the last one are selected (up to 15000 features), which means each row in x contains the HOG feature vector for a corresponding image.
# For y, the last column is selected, which contains the class labels for each image. These labels are converted to integers using astype(np.int) to ensure they are in a suitable format for classification algorithms.
# Printing Shapes: Finally, the shapes of x and y are printed to verify their structures. x should have a shape where the number of rows equals the total number of images and the number of columns equals the number of features (up to 15000 in this case). y should be a 1-dimensional array with a length equal to the total number of images, where each element is a class label.

# %%
x = concatenated_array[:, :15000]   # selects columns up to 15000 for x
y = concatenated_array[:, -1]       # selects the last column for y
y = y.astype(np.int)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_17560\3749396095.py:3: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = y.astype(np.int)

# %% [markdown]
# Shape of the Concatenated Array: The shape of the concatenated array is printed to provide insight into the data structure. The number of rows in this array equals the total number of images across all classes, and the number of columns corresponds to the number of features plus one for the class label.

# %%
print(x.shape)  # prints the shape of x
print(y.shape)  # prints the shape of y
# Out:
# (2870, 15000)
# (2870,)

# %% [markdown]
# #### PCA

# %% [markdown]
# This code segment employs Principal Component Analysis (PCA), a dimensionality reduction technique, to analyze and visualize the variance explained by the components extracted from the HOG (Histogram of Oriented Gradients) features of brain scans. Here's a breakdown of each step and its purpose:
#
# PCA Object Creation: A PCA object is instantiated without specifying the number of components. This means that PCA will consider as many components as there are features in the dataset (x) by default, aiming to capture the entirety of the variance in the data.
#
# Fitting the PCA Model: The PCA model is fit to the HOG features stored in x. This process involves calculating the eigenvalues and eigenvectors of the covariance matrix of x, which are used to determine the principal components. These components are the directions in the feature space that maximize the variance of the projected data.
#
# Cumulative Explained Variance Ratio: The explained variance ratio of each principal component is calculated. This ratio indicates the proportion of the dataset's total variance that is captured by each principal component. The cumulative sum of these ratios (cumulative_var_ratio) is then computed to understand how much of the total variance is explained by the first n components combined.
#
# Explained Variance Ratio Output: The explained variance ratio for each principal component is printed. These values give insight into the importance of each component—higher values mean a component captures more of the data's variance.
#
# Variance Plot: A line plot is created to visualize the cumulative explained variance ratio against the number of components. This plot is crucial for determining the number of components needed to capture a significant portion of the variance in the data. The x-axis represents the number of components, and the y-axis represents the cumulative explained variance ratio.
#
# The xlabel 'Number of Components' indicates the principal components on the x-axis.
# The ylabel 'Cumulative Explained Variance Ratio' indicates the proportion of the dataset's total variance explained by the first n components on the y-axis.
# The title 'cumulative variance plot.' labels the plot for clarity.
# The purpose of this analysis is to understand the dimensionality of the HOG feature space and to identify how many principal components are necessary to capture most of the variance in the data. This is often used to reduce the number of features before applying machine learning models, improving computational efficiency and potentially reducing overfitting by eliminating noise and less informative features.

# %%
from sklearn.decomposition import PCA
# Create a PCA object
pca = PCA()

# Fit the PCA model to the HOG features
pca.fit(x)

# Calculate the cumulative explained variance ratio
cumulative_var_ratio = np.cumsum(pca.explained_variance_ratio_)
print(pca.explained_variance_ratio_)

# Plot the explained variance ratio against number of components
plt.plot(cumulative_var_ratio)
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.title('cumulative variance plot.')
plt.show()
# Out:
# [1.02433216e-01 3.17391521e-02 2.01253314e-02 ... 1.07621256e-34
#  1.01781537e-34 8.68049916e-35]

# %% [markdown]
# PCA Transformation:
#
# pca.transform(x): This line applies the PCA transformation to the HOG feature matrix x. PCA is a dimensionality reduction technique that identifies the axes (principal components) along which the variance in the data is maximized. By projecting the data onto these axes, it's possible to reduce the number of dimensions (features) while retaining most of the variance (information) in the data. The result, B, is the transformed dataset where each row represents an image and columns represent the principal components. The number of columns in B is equal to the number of components in the PCA model, which was fit to the data earlier.
# Converting to DataFrame:
#
# B = pd.DataFrame(B): This line converts the transformed feature matrix B into a pandas DataFrame. This is often done for ease of data manipulation and to utilize pandas' functionality for data analysis, as DataFrames are a more flexible and intuitive structure for tabular data.
# Fitting PCA with a Specified Number of Components:
#
# pca = PCA(n_components=100): Here, a new PCA object is created with a specified number of components (n_components=100). This means that when this PCA model is fit and applied to the data, it will reduce the dimensionality of the data to 100 principal components, regardless of the original number of features.
# pca.fit(x): This line fits the new PCA model to the HOG features (x). The PCA model learns the 100 principal components that capture the most variance in the data. This fitting process involves computing the eigenvectors (principal components) and eigenvalues (explained variance) of the data's covariance matrix.
# The purpose of these operations is to reduce the dimensionality of the feature set to make subsequent machine learning models more efficient and potentially more effective. By reducing the number of features to a set of principal components that capture the majority of the variance in the data, it's possible to speed up training times, reduce the risk of overfitting, and possibly improve the generalization performance of the models. The choice of 100 components is a balance between retaining enough information (variance) and reducing the feature space to a manageable size.

# %%
B = pca.transform(x)
B = pd.DataFrame(B)
B
# Out:
#            0         1         2         3         4         5         6     \
# 0     15.627938 -1.735195  2.216702 -0.390751  0.591251 -4.945496  3.877707
# 1     13.813557 -2.873029  1.346396  2.829213 -3.363437 -0.544171 -3.441135
# 2     -5.965256  3.306897  5.130068  7.413554  2.121487 -2.256332 -0.150310
# 3     -8.589394  3.723193  4.405952  0.521718  3.436637 -2.386648 -1.302875
# 4     -8.677028  2.859252  4.761868 -2.080242  3.014057 -2.268946 -1.591664
# ...         ...       ...       ...       ...       ...       ...       ...
# 2865 -12.260603 -1.385491 -3.213993  0.749819 -2.992446  0.995263  5.257908
# 2866 -11.814813 -1.647151 -2.797724  0.836545 -3.312577  1.711157  5.308228
# 2867 -11.911042 -2.117625 -2.939042  0.571009 -2.992766  1.243995  4.818402
# 2868  -5.708559  3.051829 -6.307533  1.517266 -0.740264 -4.589578 -0.884442
# 2869  -6.119149  3.049662 -6.325550  1.329785 -0.164749 -4.728389 -0.706986
#
#           7         8         9     ...          2860          2861  \
# 0     0.938133  2.946141 -0.285276  ...  9.020562e-17 -7.632783e-17
# 1    -1.955498  0.034826 -0.861259  ...  1.401657e-15 -3.307250e-15
# 2    -1.332672 -1.504574  0.238726  ...  2.500604e-15  3.755676e-16
# 3    -1.150471 -3.603522  0.947297  ...  2.027892e-15  6.331741e-16
# 4    -1.386946 -4.032524  1.296201  ... -7.303186e-16  1.987993e-15
# ...        ...       ...       ...  ...           ...           ...
# 2865  1.465123 -1.821633  4.843168  ... -4.727121e-16  4.302114e-16
# 2866  1.037922 -2.006318  4.521808  ... -7.546047e-16 -4.104789e-16
# 2867  0.993460 -1.154225  3.645952  ... -8.743006e-16 -6.071532e-18
# 2868  8.252009 -1.167658 -1.616995  ...  1.643650e-15  5.813492e-16
# 2869  8.142472 -1.395635 -1.530937  ...  1.203898e-15  2.190088e-16
#
#               2862          2863          2864          2865          2866  \
# 0     1.509209e-16 -4.952636e-16  2.602085e-16 -6.713380e-16 -7.784572e-17
# 1    -3.282964e-15 -2.361826e-15 -3.608225e-16  1.734723e-17 -8.220421e-16
# 2     2.956728e-15  1.453698e-15 -2.749537e-15  9.948639e-16 -5.752777e-16
# 3    -1.073794e-15  1.859624e-15 -6.678685e-16  3.264099e-15 -4.109126e-16
# 4    -1.075529e-16  2.571077e-15 -3.894454e-15  2.060851e-15 -1.613293e-16
# ...            ...           ...           ...           ...           ...
# 2865  1.726050e-16  7.077672e-16  2.359224e-16  1.535230e-16  3.300311e-16
# 2866  3.096481e-16 -4.024558e-16  4.475587e-16  2.914335e-16 -2.151057e-16
# 2867 -4.302114e-16 -2.810252e-16 -2.428613e-17  3.330669e-16  4.336809e-17
# 2868  8.153200e-17 -1.394284e-15 -4.631712e-16 -9.402201e-16 -1.110223e-15
# 2869  7.962381e-16  7.034304e-16  3.521489e-16 -4.510281e-17 -9.228729e-16
#
#               2867          2868          2869
# 0    -1.096345e-15  4.770490e-16 -2.445960e-16
# 1    -2.754741e-15  1.032160e-15  2.256875e-15
# 2    -1.428545e-15  4.753142e-16  4.595865e-16
# 3     7.251144e-16  1.354819e-15  1.016548e-15
# 4     1.092876e-15 -1.547373e-15  1.708703e-16
# ...            ...           ...           ...
# 2865 -1.561251e-16 -7.806256e-18 -6.318730e-16
# 2866  1.403391e-15 -1.890849e-16 -2.775558e-17
# 2867 -1.561251e-17 -1.495332e-15  4.787837e-16
# 2868 -3.452100e-16 -1.576430e-16 -3.226586e-16
# 2869  9.410875e-17 -8.283305e-17  2.081668e-16
#
# [2870 rows x 2870 columns]

# %%
pca = PCA(n_components=100)
pca.fit(x)
# Out:
# PCA(n_components=100)

# %% [markdown]
# Saving the PCA Model
# The PCA model that was previously fit to the HOG features is serialized (saved) to disk using Python's pickle module, allowing it to be loaded and used later without retraining. The file is named 'PCA_model.sav'.
# Transforming Features Using PCA and Preparing Final Data

# %%
# save the model to disk
import joblib
filename = 'PCA_model.sav'
pickle.dump(pca, open(filename, 'wb'))

# %% [markdown]
# Transforming Features Using PCA and Preparing Final Data
# The HOG features in x are transformed using the previously trained PCA model to reduce dimensionality. This transformed feature set is converted into a pandas DataFrame, B.

# %%
B = pca.transform(x)
B = pd.DataFrame(B)
B
# Out:
#              0         1         2         3         4         5         6   \
# 0     15.627938 -1.735195  2.216702 -0.390751  0.591251 -4.945496  3.877707
# 1     13.813557 -2.873029  1.346396  2.829213 -3.363437 -0.544171 -3.441135
# 2     -5.965256  3.306897  5.130068  7.413554  2.121487 -2.256332 -0.150310
# 3     -8.589394  3.723193  4.405952  0.521718  3.436637 -2.386648 -1.302875
# 4     -8.677028  2.859252  4.761868 -2.080242  3.014057 -2.268946 -1.591664
# ...         ...       ...       ...       ...       ...       ...       ...
# 2865 -12.260603 -1.385491 -3.213993  0.749819 -2.992446  0.995263  5.257908
# 2866 -11.814813 -1.647151 -2.797724  0.836545 -3.312577  1.711157  5.308228
# 2867 -11.911042 -2.117625 -2.939042  0.571009 -2.992766  1.243995  4.818402
# 2868  -5.708559  3.051829 -6.307533  1.517266 -0.740264 -4.589578 -0.884442
# 2869  -6.119149  3.049662 -6.325550  1.329785 -0.164749 -4.728389 -0.706986
#
#             7         8         9   ...        90        91        92  \
# 0     0.938133  2.946141 -0.285276  ...  0.242042  0.573684 -0.134168
# 1    -1.955498  0.034826 -0.861259  ...  0.660068 -0.436143  0.394582
# 2    -1.332672 -1.504574  0.238726  ...  0.744465 -0.954531  0.527825
# 3    -1.150471 -3.603522  0.947297  ...  0.950739 -1.335615 -0.270340
# 4    -1.386946 -4.032524  1.296202  ...  0.316339 -1.014438 -0.960739
# ...        ...       ...       ...  ...       ...       ...       ...
# 2865  1.465123 -1.821633  4.843167  ...  1.247802  0.647645 -0.632903
# 2866  1.037922 -2.006318  4.521808  ...  1.720422  0.687735 -0.602742
# 2867  0.993460 -1.154225  3.645951  ...  2.035223  0.553487 -0.846134
# 2868  8.252009 -1.167658 -1.616995  ...  0.138892  0.142677  0.607325
# 2869  8.142472 -1.395635 -1.530937  ... -0.085143  0.088292  0.592477
#
#             93        94        95        96        97        98        99
# 0    -0.265885  0.893967 -0.195656 -0.615855  0.457960  0.022795 -0.170974
# 1     0.789019 -0.137394 -0.687626 -0.479953 -0.488944  0.473024 -0.143774
# 2     0.687570  0.568427  0.853321  0.434545  1.018838 -0.431596 -0.759334
# 3    -1.189087 -0.286419 -0.105454 -0.001851 -0.673364 -0.941132  0.303493
# 4    -0.192288  1.067034  0.201071 -0.317559 -0.022925 -1.532952  1.295024
# ...        ...       ...       ...       ...       ...       ...       ...
# 2865  1.122068 -0.490490  0.256737  0.395372  0.684092  0.508325  0.362434
# 2866  0.804681  0.512112  0.027892  0.008526  0.339904  0.729118  0.022834
# 2867  0.681446  0.087757  0.605949  0.705301 -0.167388  1.356298  0.030337
# 2868 -0.457033 -0.667145 -0.471767  0.731323 -1.361992  0.088085 -0.943841
# 2869 -0.273182 -0.402588 -0.514901  1.081634 -0.422401 -0.361550 -1.277511
#
# [2870 rows x 100 columns]

# %% [markdown]
# The class labels stored in y are concatenated to B as the final column, ensuring each row in B now consists of the principal components followed by the corresponding class label. This forms the complete dataset for training machine learning models.

# %%
#Concatinate the Class ID's 
B=pd.concat([B, pd.DataFrame(y)],axis=1)
B
# Out:
#              0         1         2         3         4         5         6   \
# 0     15.627938 -1.735195  2.216702 -0.390751  0.591251 -4.945496  3.877707
# 1     13.813557 -2.873029  1.346396  2.829213 -3.363437 -0.544171 -3.441135
# 2     -5.965256  3.306897  5.130068  7.413554  2.121487 -2.256332 -0.150310
# 3     -8.589394  3.723193  4.405952  0.521718  3.436637 -2.386648 -1.302875
# 4     -8.677028  2.859252  4.761868 -2.080242  3.014057 -2.268946 -1.591664
# ...         ...       ...       ...       ...       ...       ...       ...
# 2865 -12.260603 -1.385491 -3.213993  0.749819 -2.992446  0.995263  5.257908
# 2866 -11.814813 -1.647151 -2.797724  0.836545 -3.312577  1.711157  5.308228
# 2867 -11.911042 -2.117625 -2.939042  0.571009 -2.992766  1.243995  4.818402
# 2868  -5.708559  3.051829 -6.307533  1.517266 -0.740264 -4.589578 -0.884442
# 2869  -6.119149  3.049662 -6.325550  1.329785 -0.164749 -4.728389 -0.706986
#
#             7         8         9   ...        91        92        93  \
# 0     0.938133  2.946141 -0.285276  ...  0.573684 -0.134168 -0.265885
# 1    -1.955498  0.034826 -0.861259  ... -0.436143  0.394582  0.789019
# 2    -1.332672 -1.504574  0.238726  ... -0.954531  0.527825  0.687570
# 3    -1.150471 -3.603522  0.947297  ... -1.335615 -0.270340 -1.189087
# 4    -1.386946 -4.032524  1.296202  ... -1.014438 -0.960739 -0.192288
# ...        ...       ...       ...  ...       ...       ...       ...
# 2865  1.465123 -1.821633  4.843167  ...  0.647645 -0.632903  1.122068
# 2866  1.037922 -2.006318  4.521808  ...  0.687735 -0.602742  0.804681
# 2867  0.993460 -1.154225  3.645951  ...  0.553487 -0.846134  0.681446
# 2868  8.252009 -1.167658 -1.616995  ...  0.142677  0.607325 -0.457033
# 2869  8.142472 -1.395635 -1.530937  ...  0.088292  0.592477 -0.273182
#
#             94        95        96        97        98        99  0
# 0     0.893967 -0.195656 -0.615855  0.457960  0.022795 -0.170974   0
# 1    -0.137394 -0.687626 -0.479953 -0.488944  0.473024 -0.143774   0
# 2     0.568427  0.853321  0.434545  1.018838 -0.431596 -0.759334   0
# 3    -0.286419 -0.105454 -0.001851 -0.673364 -0.941132  0.303493   0
# 4     1.067034  0.201071 -0.317559 -0.022925 -1.532952  1.295024   0
# ...        ...       ...       ...       ...       ...       ...  ..
# 2865 -0.490490  0.256737  0.395372  0.684092  0.508325  0.362434   3
# 2866  0.512112  0.027892  0.008526  0.339904  0.729118  0.022834   3
# 2867  0.087757  0.605949  0.705301 -0.167388  1.356298  0.030337   3
# 2868 -0.667145 -0.471767  0.731323 -1.361992  0.088085 -0.943841   3
# 2869 -0.402588 -0.514901  1.081634 -0.422401 -0.361550 -1.277511   3
#
# [2870 rows x 101 columns]

# %% [markdown]
# This final dataset is then saved to a CSV file named 'Final_HOG_Feature.csv' without headers or indexes, making it suitable for loading as raw data.

# %%
#Creating Final Feature File after applying PCA 
csv_data1=B.to_csv('Final_HOG_Feature.csv', mode='w',header=False,index=False)

# %% [markdown]
# Loading and Preprocessing the Final Dataset
# The saved CSV file is loaded into a pandas DataFrame, train_data, with no header as the CSV doesn't contain column names.

# %% [markdown]
# The script checks for any missing values (NaN) in the data. Handling missing values is crucial to prevent errors during model training.

# %%
train_data = pd.read_csv('Final_HOG_Feature.csv',header=None)
     

#Check for NaN under a single DataFrame column
train_data.isnull().values.any()
# Out:
# False

# %% [markdown]
# The features (principal components) and labels are separated into X and Y, respectively. X contains all columns except the last one, which is assumed to be the class label column. Y is the last column, containing the class labels.

# %%
X = train_data.drop(columns= 100, axis=1)

# %%
X
# Out:
#              0         1         2         3         4         5         6   \
# 0     15.627938 -1.735195  2.216702 -0.390751  0.591251 -4.945496  3.877707
# 1     13.813557 -2.873029  1.346396  2.829213 -3.363437 -0.544171 -3.441135
# 2     -5.965256  3.306897  5.130068  7.413554  2.121487 -2.256332 -0.150310
# 3     -8.589394  3.723193  4.405952  0.521718  3.436637 -2.386648 -1.302875
# 4     -8.677028  2.859252  4.761868 -2.080242  3.014057 -2.268946 -1.591664
# ...         ...       ...       ...       ...       ...       ...       ...
# 2865 -12.260603 -1.385491 -3.213993  0.749819 -2.992446  0.995263  5.257908
# 2866 -11.814813 -1.647151 -2.797724  0.836545 -3.312577  1.711157  5.308228
# 2867 -11.911042 -2.117625 -2.939042  0.571009 -2.992766  1.243995  4.818402
# 2868  -5.708559  3.051829 -6.307533  1.517266 -0.740264 -4.589578 -0.884442
# 2869  -6.119149  3.049662 -6.325550  1.329785 -0.164749 -4.728389 -0.706986
#
#             7         8         9   ...        90        91        92  \
# 0     0.938133  2.946141 -0.285276  ...  0.242042  0.573684 -0.134168
# 1    -1.955498  0.034826 -0.861259  ...  0.660068 -0.436143  0.394582
# 2    -1.332672 -1.504574  0.238726  ...  0.744465 -0.954531  0.527825
# 3    -1.150471 -3.603522  0.947297  ...  0.950739 -1.335615 -0.270340
# 4    -1.386946 -4.032524  1.296202  ...  0.316339 -1.014438 -0.960739
# ...        ...       ...       ...  ...       ...       ...       ...
# 2865  1.465123 -1.821633  4.843167  ...  1.247802  0.647645 -0.632903
# 2866  1.037922 -2.006318  4.521808  ...  1.720422  0.687735 -0.602742
# 2867  0.993460 -1.154225  3.645951  ...  2.035223  0.553487 -0.846134
# 2868  8.252009 -1.167658 -1.616995  ...  0.138892  0.142677  0.607325
# 2869  8.142472 -1.395635 -1.530937  ... -0.085143  0.088292  0.592477
#
#             93        94        95        96        97        98        99
# 0    -0.265885  0.893967 -0.195656 -0.615855  0.457960  0.022795 -0.170974
# 1     0.789019 -0.137394 -0.687626 -0.479953 -0.488944  0.473024 -0.143774
# 2     0.687570  0.568427  0.853321  0.434545  1.018838 -0.431596 -0.759334
# 3    -1.189087 -0.286419 -0.105454 -0.001851 -0.673364 -0.941132  0.303493
# 4    -0.192288  1.067034  0.201071 -0.317559 -0.022925 -1.532952  1.295024
# ...        ...       ...       ...       ...       ...       ...       ...
# 2865  1.122068 -0.490490  0.256737  0.395372  0.684092  0.508325  0.362434
# 2866  0.804681  0.512112  0.027892  0.008526  0.339904  0.729118  0.022834
# 2867  0.681446  0.087757  0.605949  0.705301 -0.167388  1.356298  0.030337
# 2868 -0.457033 -0.667145 -0.471767  0.731323 -1.361992  0.088085 -0.943841
# 2869 -0.273182 -0.402588 -0.514901  1.081634 -0.422401 -0.361550 -1.277511
#
# [2870 rows x 100 columns]

# %%
Y  = train_data[100]

# %%
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2865    3
# 2866    3
# 2867    3
# 2868    3
# 2869    3
# Name: 100, Length: 2870, dtype: int64

# %%
 ##Applying Classifiers With K Fold Cross Validation

# %% [markdown]
# #### Applying Models

# %% [markdown]
# Logistic Regression

# %%
#Logistic Regression

k = 5
kf = KFold(n_splits=k, random_state=None)
model_LR = LogisticRegression(solver= 'liblinear')
 
acc_score = []
 
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = Y[train_index] , Y[test_index]
     
    model_LR.fit(X_train,y_train)
    pred_values = model_LR.predict(X_test)
     
    acc = accuracy_score(pred_values , y_test)
    acc_score.append(acc)
     
avg_acc_score_lr = sum(acc_score)/k
 
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score_lr))
joblib.dump(model_LR, "LG_HOG.sav")
# Out:
# accuracy of each fold - [0.6794425087108014, 0.6463414634146342, 0.37456445993031356, 0.5975609756097561, 0.5993031358885017]
# Avg accuracy : 0.5794425087108014
# ['LG_HOG.sav']

# %% [markdown]
# Random Forest

# %%
#Random Forest

k = 5
kf = KFold(n_splits=k, random_state=None)
model_RF = RandomForestClassifier()
 
acc_score = []
 
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = Y[train_index] , Y[test_index]
     
    model_RF.fit(X_train,y_train)
    pred_values = model_RF.predict(X_test)
     
    acc = accuracy_score(pred_values , y_test)
    acc_score.append(acc)
     
avg_acc_score_rf = sum(acc_score)/k
 
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score_rf))
# Out:
# accuracy of each fold - [0.47038327526132406, 0.6655052264808362, 0.30139372822299654, 0.4442508710801394, 0.3048780487804878]
# Avg accuracy : 0.43728222996515675

# %% [markdown]
# KNN Classifier

# %%
k = 5
kf = KFold(n_splits=k, random_state=None)
model_knn = KNeighborsClassifier()

acc_score = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index, :].to_numpy(), X.iloc[test_index, :].to_numpy()  # Convert to NumPy array
    y_train, y_test = Y[train_index], Y[test_index]
    
    model_knn.fit(X_train, y_train)
    pred_values = model_knn.predict(X_test)
    
    acc = accuracy_score(pred_values, y_test)
    acc_score.append(acc)

avg_acc_score_kn = sum(acc_score) / k

print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score_kn))
# Out:
# accuracy of each fold - [0.6393728222996515, 0.6498257839721254, 0.3118466898954704, 0.5156794425087108, 0.6167247386759582]
# Avg accuracy : 0.5466898954703833

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\lenovo\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: scipy in c:\users\lenovo\anaconda3\lib\site-packages (from xgboost) (1.7.3)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from xgboost) (1.21.5)

# %% [markdown]
# XGBoost

# %%
import xgboost as xgb

# %%
 #XGBoost

k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=None)

model_xgb = xgb.XGBClassifier()

acc_score = []
y_pred_list = []
y_test_list = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index, :], X.iloc[test_index, :]
    y_train, y_test = Y[train_index], Y[test_index]

    model_xgb.fit(X_train, y_train)

    y_pred = model_xgb.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    acc_score.append(acc)

    y_pred_list.extend(y_pred)
    y_test_list.extend(y_test)

avg_acc_score_xg = sum(acc_score) / k

print('Accuracy of each fold - {}'.format(acc_score))
print('Average accuracy: {}'.format(avg_acc_score_xg))

joblib.dump(model_xgb, "xgb.sav")
# Out:
# Accuracy of each fold - [0.9006968641114983, 0.9233449477351916, 0.8797909407665505, 0.8780487804878049, 0.8954703832752613]
# Average accuracy: 0.8954703832752614
# ['xgb.sav']

# %% [markdown]
# AdaBoost

# %%
#AdaBoost

k = 5
kf = KFold(n_splits=k, random_state=None)
model_AB = AdaBoostClassifier()
 
acc_score = []
 
for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index,:],X.iloc[test_index,:]
    y_train , y_test = Y[train_index] , Y[test_index]
     
    model_AB.fit(X_train,y_train)
    pred_values = model_AB.predict(X_test)
     
    acc = accuracy_score(pred_values , y_test)
    acc_score.append(acc)
     
avg_acc_score_ab = sum(acc_score)/k
 
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score_ab))
# Out:
# accuracy of each fold - [0.2787456445993031, 0.45818815331010454, 0.3170731707317073, 0.25435540069686413, 0.39198606271777003]
# Avg accuracy : 0.3400696864111498

# %% [markdown]
# SVM

# %%
#SVM

k = 5
kf = KFold(n_splits=k, random_state=None)
model_SVM = SVC(kernel='linear')

acc_score = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index, :], X.iloc[test_index, :]
    y_train, y_test = Y[train_index], Y[test_index]

    model_SVM.fit(X_train, y_train)
    pred_values = model_SVM.predict(X_test)

    acc = accuracy_score(pred_values, y_test)
    acc_score.append(acc)

avg_acc_score_svm = sum(acc_score) / k

print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score_svm))
# Out:
# accuracy of each fold - [0.686411149825784, 0.6898954703832753, 0.3606271777003484, 0.6306620209059234, 0.6149825783972126]
# Avg accuracy : 0.5965156794425088

# %% [markdown]
# Decision Tree

# %%
#Decision Tree

k = 5
kf = KFold(n_splits=k, random_state=None)
model_DT = DecisionTreeClassifier()

acc_score = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index, :], X.iloc[test_index, :]
    y_train, y_test = Y[train_index], Y[test_index]

    model_DT.fit(X_train, y_train)
    pred_values = model_DT.predict(X_test)

    acc = accuracy_score(pred_values, y_test)
    acc_score.append(acc)

avg_acc_score_dt = sum(acc_score) / k

print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score_dt))
# Out:
# accuracy of each fold - [0.43205574912891986, 0.6097560975609756, 0.34668989547038326, 0.4965156794425087, 0.3205574912891986]
# Avg accuracy : 0.4411149825783972

# %% [markdown]
# Gradient Boosting

# %%
#Gradient Boosting

k = 5
kf = KFold(n_splits=k, random_state=None)
model_GBM = GradientBoostingClassifier()

acc_score = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index, :], X.iloc[test_index, :]
    y_train, y_test = Y[train_index], Y[test_index]

    model_GBM.fit(X_train, y_train)
    pred_values = model_GBM.predict(X_test)

    acc = accuracy_score(pred_values, y_test)
    acc_score.append(acc)

avg_acc_score_gb = sum(acc_score) / k

print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score_gb))
# Out:
# accuracy of each fold - [0.4808362369337979, 0.681184668989547, 0.3310104529616725, 0.5592334494773519, 0.4808362369337979]
# Avg accuracy : 0.5066202090592334

# %%
##Results
print("Pituitary Tumor")
#Reading Image
img = cv2.imread("pituitary.jpg")
plt.imshow(img2)
plt.show()

#resize total  image size to 200 x 200
resize=(200,200)
img1=cv2.resize(img,resize)

#Grayscaling the Image
gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

# Apply median filter with kernel size 3x3
median_img = cv2.medianBlur(gray, 3)

#Applying HOG Feature Descriptor
fd, hog_image = hog(median_img, orientations=6, pixels_per_cell=(4, 4),  transform_sqrt=True,cells_per_block=(1, 1), visualize=True)

# Convert the descriptor array into a DataFrame format
print("descriptor shape ", i, " : ", fd.shape)

#Getting data in a Dataframe
df = pd.DataFrame(fd)

#Appling Transpose to dataframe to convert rows into column and column into rows
df_transposed = df.transpose()
df_transposed

#Loading the PCA Model
pca = joblib.load('PCA_model.sav')

#Applying the PCA to extracted Data
fd_pca = pca.transform(df_transposed)
     

# Load the XGBoost model as it provides highest Accuracy
loaded_model = joblib.load("xgb.sav")

# Use the loaded model for prediction
y_pred = loaded_model.predict(fd_pca)

print(y_pred)
# Glioma = 0 
# Meningioma = 1
# No tumor = 2
# Pituitary = 3

if y_pred == 0:
    print("Given Image is of Glioma Tumor")
elif y_pred == 1:
    print("Given Image is of Meningioma Tumor")
elif y_pred == 2:
    print("Given Image is of No Tumor")
else:
    print("Given Image is of Pituitary Tumor")
    
print("Glioma Tumor")
img2 = cv2.imread("glioma.jpg")
plt.imshow(img2)
plt.show()

#resize total  image size to 200 x 200
resize=(200,200)
img3=cv2.resize(img2,resize)

#Grayscaling the Image
gray = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

# Apply median filter with kernel size 3x3
median_img = cv2.medianBlur(gray, 3)

#Applying HOG Feature Descriptor
fd, hog_image = hog(median_img, orientations=6, pixels_per_cell=(4, 4),  transform_sqrt=True,cells_per_block=(1, 1), visualize=True)

# Convert the descriptor array into a DataFrame format
print("descriptor shape ", i, " : ", fd.shape)

#Getting data in a Dataframe
df = pd.DataFrame(fd)

#Appling Transpose to dataframe to convert rows into column and column into rows
df_transposed = df.transpose()
df_transposed

#Loading the PCA Model
pca = joblib.load('PCA_model.sav')

#Applying the PCA to extracted Data
fd_pca = pca.transform(df_transposed)
     

# Load the XGBoost model as it provides highest Accuracy
loaded_model = joblib.load("xgb.sav")

# Use the loaded model for prediction
y_pred = loaded_model.predict(fd_pca)

print(y_pred)
# Glioma = 0 
# Meningioma = 1
# No tumor = 2
# Pituitary = 3

if y_pred == 0:
    print("Given Image is of Glioma Tumor")
elif y_pred == 1:
    print("Given Image is of Meningioma Tumor")
elif y_pred == 2:
    print("Given Image is of No Tumor")
else:
    print("Given Image is of Pituitary Tumor")
# Out:
# Pituitary Tumor
# descriptor shape  3  :  (15000,)
# [1]
# Given Image is of Meningioma Tumor
# Glioma Tumor
# descriptor shape  3  :  (15000,)
# [0]
# Given Image is of Glioma Tumor

# %%
import matplotlib.pyplot as plt

# Modellerin ve doğruluk değerlerinin tanımlanması
models = ['GBM', 'Decision Tree', 'SVM', 'XGBoost', 'KNN', 'Random Forest', 'Logistic Regression']
accuracies = [avg_acc_score_gb, avg_acc_score_dt, avg_acc_score_svm,  avg_acc_score_xg, avg_acc_score_kn, avg_acc_score_rf, avg_acc_score_lr]

# Grafik oluşturma
plt.figure(figsize=(10, 6))
plt.bar(models, accuracies, color='skyblue')
plt.xlabel('Models')
plt.ylabel('Average Accuracy')
plt.title('Average Accuracy of Different Models')
plt.ylim(0, 1)  # Y eksenini 0 ile 1 arasında sınırla
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45)  # X eksenindeki yazıları 45 derece döndür
plt.show()
